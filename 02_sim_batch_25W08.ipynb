# %% [markdown]
# # Simulation

# %% [markdown]
# ## **Batch Sim**

# %%
import importlib
import pandas as pd
from openai import OpenAI
import os
import json
import traceback
import sys

import brikasutils as bu
import shared_utils as utils
import survey
importlib.reload(bu)
importlib.reload(utils)
importlib.reload(survey)

SAVE_SIMULATION_DIR = "batch/output"
queue = bu.FileRunQueue(queue_folder_path="batch/queue", completed_folder_path="batch/done")
report_live_csv = bu.LiveCSV("batch/run_reports/uniform_V7.csv")
timer = bu.Benchmarker()

for filepath in queue:
    timer.mark_start(filepath)

    try: 
        ########## Handle batch stuff ########
        filename = os.path.splitext(os.path.basename(filepath))[0]
        with open(filepath, 'r') as f:
            rundata = json.load(f)

        # Load prompt file
        with open(rundata["instructions"]["prompt_file"], 'r') as f:
            final_prompts = json.load(f)

        # Make the surv
        if rundata["instructions"]["survey_type"] == "KanoSurvey":
            surv = survey.KanoSurvey()
        elif rundata["instructions"]["survey_type"] == "PersonalitySurvey":
            surv = survey.PersonalitySurvey()
        else:
            raise Exception("Invalid survey type")

        timestamp = bu.get_timestamp()
        ######### Run Simulation ########
        SIMULATION_NAMEID = filename
        LIMIT = rundata["instructions"]["LIMIT"] if "LIMIT" in rundata["instructions"] else None
        AUTO_INFO = {
            "date": timestamp,
            **rundata["info"], # unpacked from rundata
            "limit": LIMIT,
            "prompt_count": min(len(final_prompts), LIMIT) if LIMIT != None else len(final_prompts),
            "avg_tokens_in_prompt": round(utils.describe_prompts(final_prompts)["total_all_prompt_tokens"]/len(final_prompts)),
        }
        SETTINGS = {
            **rundata["settings"], # unpacked from rundata
        }

        # client depends on if it's local or not
        if rundata["instructions"]["isLocal"]:
            client = OpenAI(
                base_url = 'http://localhost:11434/v1',
                api_key='ollama', # required, but unused
            )
        else:
            client = OpenAI(
                api_key=os.environ.get("OPENAI_API_KEY"),
            )

        completions = []
        l = len(final_prompts)

        for i, (prompt, question) in enumerate(list(zip(final_prompts, surv.questions))):
            if LIMIT != None and i > LIMIT:
                break

            print(f"{i}/{l}...", end="\t") # Print progress
            # Send the Request
            full_response = client.chat.completions.create(
                messages=prompt,
                **SETTINGS,
            )
            r = full_response.choices[0].message.content

            completions.append({'question': question, 'answer': r})

            print(f"{question}: {r}")
            
        ############ Save Important results
        df = pd.DataFrame(completions)
        bu.if_dir_not_exist_make(SAVE_SIMULATION_DIR)
        df.to_csv(f"{SAVE_SIMULATION_DIR}/{SIMULATION_NAMEID}_simulation.csv", index=False)
        bu.if_dir_not_exist_make(os.path.join(SAVE_SIMULATION_DIR, "info"))
        bu.quickJSON({"settings": SETTINGS, "info": AUTO_INFO}, f"{SAVE_SIMULATION_DIR}/info/{SIMULATION_NAMEID}_info.json")

        status = "OK"
    
    except Exception:
        print(f"##### Error while running {filename}.")
        error_string = traceback.format_exc()
        print(error_string)
        status = "Failed"

    ########### Time the run
    try:
        time_taken = timer.mark_end(filepath)
    except:
        print("Error while timing run: ")
        print(traceback.format_exc())
        time_taken = None

    ########### Report the run
    try:
        new_report = {
            "filename": filename,
            "timestamp": timestamp,
            "time_taken": time_taken,
            "status": status,
            **rundata["instructions"],
            "error": error_string if status == "Failed" else "",
        }

        tmp = bu.convert_dicts_to_table([new_report])
        report_live_csv.append_data(tmp[1], tmp[0])
    except Exception as e:
        print(f"Error while reporting: ")
        traceback.print_exc()

    print(f"Processed {filename}. Stauts: {status}")

timer.print_total_execution_time()
# Out:
# LiveCSV: File /Users/et/Desktop/Thesis/batch/run_reports/uniform_V7.csv not existing. Creating new.
# brikasutils.quickCSV: Saved 0 as batch/run_reports/uniform_V7.csv
# [1/90] Running airidas-kano-0_llama3-70b_V7_1.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I CAN TOLERATE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I DISLIKE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I DISLIKE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I CAN TOLERATE IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I CAN TOLERATE IT
# 10/40...	What would you say if the game had realistic game physics?: I LIKE IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I CAN TOLERATE IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I CAN TOLERATE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I DISLIKE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I LIKE IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I CAN TOLERATE IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I LIKE IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I CAN TOLERATE IT
# 18/40...	What would you say if the game had cutscenes?: I EXPECT IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I DISLIKE IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I LIKE IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I DISLIKE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I LIKE IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I CAN TOLERATE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I CAN TOLERATE IT
# 26/40...	What would you say if the game had realistic graphics?: I LIKE IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I DISLIKE IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I LIKE IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I DISLIKE IT
# 30/40...	What would you say if the game contained violent elements?: I LIKE IT
# 31/40...	What would you say if the game contained NO violent elements?: I AM NEUTRAL
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I EXPECT IT
# 37/40...	What would you say if the game did NOT have quests?: I CAN TOLERATE IT
# 38/40...	What would you say if the game had a clear ending or goal?: I EXPECT IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/airidas-kano-0_llama3-70b_V7_1.json took 1051.689s
# brikasutils.quickCSV: Saved 1 as batch/run_reports/uniform_V7.csv
# Processed airidas-kano-0_llama3-70b_V7_1. Stauts: OK
# [2/90] Running airidas-pers-0_llama3-70b_V7_0.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: AGREE
# 1/50...	I don't talk a lot.: DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT DISAGREE
# 3/50...	I keep in the background.: DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: DISAGREE
# 6/50...	I talk to a lot of different people at parties.: AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREE
# 10/50...	I get stressed out easily.: DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT DISAGREE
# 12/50...	I worry about things.: DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGRE
# 14/50...	I am easily disturbed.: DISAGREE
# 15/50...	I get upset easily.: DISAGREE
# 16/50...	I change my mood a lot.: DISAGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT AGREE
# 18/50...	I get irritated easily.: DISAGREE
# 19/50...	I often feel blue.: DISAGREE
# 20/50...	I feel little concern for others.: DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: DISAGREE
# 23/50...	I sympathize with others' feelings.: AGREE
# 24/50...	I am not interested in other people's problems.: DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: AGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: DISAGREE
# 34/50...	I get chores done right away.: DISAGREE
# 35/50...	I often forget to put things back in their proper place.: DISAGREE
# 36/50...	I like order.: NEUTRAL
# 37/50...	I shirk my duties.: DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREE
# 39/50...	I am exacting in my work.: AGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: DISAGREE
# 42/50...	I have a vivid imagination.: AGREE
# 43/50...	I am not interested in abstract ideas.: DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: DISAGREE
# 46/50...	I am quick to understand things.: AGREE
# 47/50...	I use difficult words.: DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-0_llama3-70b_V7_0.json took 1270.012s
# brikasutils.quickCSV: Saved 2 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-0_llama3-70b_V7_0. Stauts: OK
# [3/90] Running eli-pers-4000_llama3-8b_V7_0.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT DISAGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREEMENT
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT AGREE
# 12/50...	I worry about things.: SOMEWHAT DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT AGREES
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT AGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREEMENT
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT AGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT DISAGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREED
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREE
# 39/50...	I am exacting in my work.: SOMEWHAT DISAGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/eli-pers-4000_llama3-8b_V7_0.json took 169.017s
# brikasutils.quickCSV: Saved 3 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-4000_llama3-8b_V7_0. Stauts: OK
# [4/90] Running airidas-pers-4000_llama3-8b_V7_0.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT DISAGREE
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT AGREE
# 12/50...	I worry about things.: SOMEWHAT DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT AGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT AGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT AGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT DISAGREE
# 39/50...	I am exacting in my work.: SOMEWHAT DISAGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT DISAGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-4000_llama3-8b_V7_0.json took 158.42s
# brikasutils.quickCSV: Saved 4 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-4000_llama3-8b_V7_0. Stauts: OK
# [5/90] Running airidas-pers-4000_llama3-8b_V7_1.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT DISAGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: NEUTRAL
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT DISAGREE
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT AGREE
# 12/50...	I worry about things.: SOMEWHAT DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT AGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT AGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT DISAGREE
# 39/50...	I am exacting in my work.: SOMEWHAT AGREEMENT
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-4000_llama3-8b_V7_1.json took 158.233s
# brikasutils.quickCSV: Saved 5 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-4000_llama3-8b_V7_1. Stauts: OK
# [6/90] Running airidas-pers-7500_llama3-8b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT DISAGREE
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT AGREE
# 12/50...	I worry about things.: SOMEWHAT AGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT AGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT DISAGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT AGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT DISAGREE
# 33/50...	I make a mess of things.: SOMEWHAT AGREE
# 34/50...	I get chores done right away.: SOMEWHAT AGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT DISAGREE
# 39/50...	I am exacting in my work.: SOMEWHAT DISAGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT AGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-7500_llama3-8b_V7_2.json took 157.679s
# brikasutils.quickCSV: Saved 6 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-7500_llama3-8b_V7_2. Stauts: OK
# [7/90] Running airidas-pers-0_llama3-8b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT AGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT DISAGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREES
# 5/50...	I have little to say.: SOMEWHAT AGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT DISAGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT DISAGREE
# 10/50...	I get stressed out easily.: SOMEWHAT AGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT AGREE
# 12/50...	I worry about things.: SOMEWHAT AGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT AGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT DISAGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT AGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT AGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT DISAGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT DISAGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT DISAGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREE
# 39/50...	I am exacting in my work.: SOMEWHAT AGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT DISAGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT AGREEMENT
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-0_llama3-8b_V7_2.json took 133.657s
# brikasutils.quickCSV: Saved 7 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-0_llama3-8b_V7_2. Stauts: OK
# [8/90] Running eli-pers-0_llama3-8b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT AGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT AGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT DISAGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT DISAGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREE
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT DISAGREE
# 12/50...	I worry about things.: SOMEWHAT AGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREES
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT AGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT AGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT DISAGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREED
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREEMENT
# 39/50...	I am exacting in my work.: SOMEWHAT AGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/eli-pers-0_llama3-8b_V7_2.json took 107.919s
# brikasutils.quickCSV: Saved 8 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-0_llama3-8b_V7_2. Stauts: OK
# [9/90] Running eli-pers-4000_llama3-8b_V7_1.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT AGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT DISAGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT DISAGREE
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT DISAGREE
# 12/50...	I worry about things.: SOMEWHAT DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT DISAGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: SOMEWHAT AGREED
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT AGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREEMENT
# 39/50...	I am exacting in my work.: SOMEWHAT DISAGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT AGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/eli-pers-4000_llama3-8b_V7_1.json took 160.906s
# brikasutils.quickCSV: Saved 9 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-4000_llama3-8b_V7_1. Stauts: OK
# [10/90] Running eli-pers-7500_llama3-8b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: SOMEWHAT DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT AGREE
# 3/50...	I keep in the background.: SOMEWHAT DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT DISAGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREEMENT
# 10/50...	I get stressed out easily.: SOMEWHAT DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT DISAGREE
# 12/50...	I worry about things.: SOMEWHAT DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT DISAGREE
# 14/50...	I am easily disturbed.: SOMEWHAT DISAGREE
# 15/50...	I get upset easily.: SOMEWHAT DISAGREE
# 16/50...	I change my mood a lot.: SOMEWHAT DISAGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT DISAGREE
# 18/50...	I get irritated easily.: SOMEWHAT DISAGREE
# 19/50...	I often feel blue.: SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.: SOMEWHAT DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: SOMEWHAT DISAGREE
# 23/50...	I sympathize with others' feelings.: SOMEWHAT AGREE
# 24/50...	I am not interested in other people's problems.: SOMEWHAT DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: SOMEWHAT DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT AGREE
# 31/50...	I leave my belongings around.: SOMEWHAT DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: SOMEWHAT DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT AGREE
# 35/50...	I often forget to put things back in their proper place.: SOMEWHAT DISAGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: SOMEWHAT DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT DISAGREE
# 39/50...	I am exacting in my work.: SOMEWHAT DISAGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: SOMEWHAT DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT DISAGREE
# 45/50...	I do not have a good imagination.: SOMEWHAT DISAGREE
# 46/50...	I am quick to understand things.: SOMEWHAT AGREE
# 47/50...	I use difficult words.: SOMEWHAT DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/eli-pers-7500_llama3-8b_V7_2.json took 162.682s
# brikasutils.quickCSV: Saved 10 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-7500_llama3-8b_V7_2. Stauts: OK
# [11/90] Running airidas-pers-0_llama3-70b_V7_1.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: AGREE
# 1/50...	I don't talk a lot.: DISAGREE
# 2/50...	I feel comfortable around people.: SOMEWHAT DISAGREE
# 3/50...	I keep in the background.: DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: DISAGREE
# 6/50...	I talk to a lot of different people at parties.: AGREE
# 7/50...	I don't like to draw attention to myself.: DISAGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREE
# 10/50...	I get stressed out easily.: DISAGREE
# 11/50...	I am relaxed most of the time.: DISAGREE
# 12/50...	I worry about things.: DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: DISAGREE
# 15/50...	I get upset easily.: DISAGREE
# 16/50...	I change my mood a lot.: DISAGREE
# 17/50...	I have frequent mood swings.: DISAGREE
# 18/50...	I get irritated easily.: DISAGREE
# 19/50...	I often feel blue.: DISAGREE
# 20/50...	I feel little concern for others.: DISAGREE
# 21/50...	I am interested in people.: AGREE
# 22/50...	I insult people.: DISAGREE
# 23/50...	I sympathize with others' feelings.: AGREE
# 24/50...	I am not interested in other people's problems.: DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: DISAGREE
# 27/50...	I take time out for others.: SOMEWHAT AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: AGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: DISAGREE
# 34/50...	I get chores done right away.: DISAGREE
# 35/50...	I often forget to put things back in their proper place.: DISAGREE
# 36/50...	I like order.: NEUTRAL
# 37/50...	I shirk my duties.: DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT AGREE
# 39/50...	I am exacting in my work.: AGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: DISAGREE
# 42/50...	I have a vivid imagination.: AGREE
# 43/50...	I am not interested in abstract ideas.: DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: DISAGREE
# 46/50...	I am quick to understand things.: AGREE
# 47/50...	I use difficult words.: DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/airidas-pers-0_llama3-70b_V7_1.json took 1214.646s
# brikasutils.quickCSV: Saved 11 as batch/run_reports/uniform_V7.csv
# Processed airidas-pers-0_llama3-70b_V7_1. Stauts: OK
# [12/90] Running base-pers-29_llama3-70b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: AGREE
# 1/50...	I don't talk a lot.: NEUTRAL
# 2/50...	I feel comfortable around people.: AGREE
# 3/50...	I keep in the background.: DISAGREE
# 4/50...	I start conversations.: AGREE
# 5/50...	I have little to say.: AGREE
# 6/50...	I talk to a lot of different people at parties.: AGREE
# 7/50...	I don't like to draw attention to myself.: AGREE
# 8/50...	I don't mind being the center of attention.: AGREE
# 9/50...	I am quiet around strangers.: AGREE
# 10/50...	I get stressed out easily.: AGREE
# 11/50...	I am relaxed most of the time.: AGREE
# 12/50...	I worry about things.: AGREE
# 13/50...	I seldom feel blue.: AGREE
# 14/50...	I am easily disturbed.: AGREE
# 15/50...	I get upset easily.: AGREE
# 16/50...	I change my mood a lot.: AGREE
# 17/50...	I have frequent mood swings.: SOMEWHAT AGREE
# 18/50...	I get irritated easily.: AGREE
# 19/50...	I often feel blue.: AGREE
# 20/50...	I feel little concern for others.: DISAGREE
# 21/50...	I am interested in people.: AGREE
# 22/50...	I insult people.: DISAGREE
# 23/50...	I sympathize with others' feelings.: AGREE
# 24/50...	I am not interested in other people's problems.: AGREE
# 25/50...	I have a soft heart.: AGREE
# 26/50...	I am not really interested in others.: AGREE
# 27/50...	I take time out for others.: AGREE
# 28/50...	I feel others' emotions.: AGREE
# 29/50...	I make people feel at ease.: AGREE
# 30/50...	I am always prepared.: AGREE
# 31/50...	I leave my belongings around.: AGREE
# 32/50...	I pay attention to details.: AGREE
# 33/50...	I make a mess of things.: AGREE
# 34/50...	I get chores done right away.: AGREE
# 35/50...	I often forget to put things back in their proper place.: AGREE
# 36/50...	I like order.: AGREE
# 37/50...	I shirk my duties.: DISAGREE
# 38/50...	I follow a schedule.: AGREE
# 39/50...	I am exacting in my work.: AGREE
# 40/50...	I have a rich vocabulary.: AGREE
# 41/50...	I have difficulty understanding abstract ideas.: SOMEWHAT AGREE
# 42/50...	I have a vivid imagination.: AGREE
# 43/50...	I am not interested in abstract ideas.: AGREE
# 44/50...	I have excellent ideas.: AGREE
# 45/50...	I do not have a good imagination.: AGREE
# 46/50...	I am quick to understand things.: AGREE
# 47/50...	I use difficult words.: NEUTRAL
# 48/50...	I spend time reflecting on things.: AGREE
# 49/50...	I am full of ideas.: AGREE
# batch/queue/base-pers-29_llama3-70b_V7_2.json took 85.558s
# brikasutils.quickCSV: Saved 12 as batch/run_reports/uniform_V7.csv
# Processed base-pers-29_llama3-70b_V7_2. Stauts: OK
# [13/90] Running airidas-kano-0_llama3-70b_V7_0.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I CAN TOLERATE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I DISLIKE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I DISLIKE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I CAN TOLERATE IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I CAN TOLERATE IT
# 10/40...	What would you say if the game had realistic game physics?: I LIKE IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I CAN TOLERATE IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I CAN TOLERATE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I DISLIKE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I LIKE IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I CAN TOLERATE IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I LIKE IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I DISLIKE IT
# 18/40...	What would you say if the game had cutscenes?: I EXPECT IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I CAN TOLERATE IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I LIKE IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I DISLIKE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I LIKE IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I CAN TOLERATE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I CAN TOLERATE IT
# 26/40...	What would you say if the game had realistic graphics?: I LIKE IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I CAN TOLERATE IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I LIKE IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I DISLIKE IT
# 30/40...	What would you say if the game contained violent elements?: I LIKE IT
# 31/40...	What would you say if the game contained NO violent elements?: I AM NEUTRAL
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I EXPECT IT
# 37/40...	What would you say if the game did NOT have quests?: I CAN TOLERATE IT
# 38/40...	What would you say if the game had a clear ending or goal?: I LIKE IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/airidas-kano-0_llama3-70b_V7_0.json took 833.677s
# brikasutils.quickCSV: Saved 13 as batch/run_reports/uniform_V7.csv
# Processed airidas-kano-0_llama3-70b_V7_0. Stauts: OK
# [14/90] Running eli-pers-0_llama3-70b_V7_2.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.: SOMEWHAT DISAGREE
# 1/50...	I don't talk a lot.: DISAGREE
# 2/50...	I feel comfortable around people.: AGREE
# 3/50...	I keep in the background.: DISAGREE
# 4/50...	I start conversations.: SOMEWHAT AGREE
# 5/50...	I have little to say.: DISAGREE
# 6/50...	I talk to a lot of different people at parties.: SOMEWHAT AGREE
# 7/50...	I don't like to draw attention to myself.: SOMEWHAT AGREE
# 8/50...	I don't mind being the center of attention.: SOMEWHAT AGREE
# 9/50...	I am quiet around strangers.: SOMEWHAT AGREE
# 10/50...	I get stressed out easily.: DISAGREE
# 11/50...	I am relaxed most of the time.: SOMEWHAT DISAGREE
# 12/50...	I worry about things.: DISAGREE
# 13/50...	I seldom feel blue.: SOMEWHAT AGREE
# 14/50...	I am easily disturbed.: DISAGREE
# 15/50...	I get upset easily.: DISAGREE
# 16/50...	I change my mood a lot.: DISAGREE
# 17/50...	I have frequent mood swings.: DISAGREE
# 18/50...	I get irritated easily.: DISAGREE
# 19/50...	I often feel blue.: DISAGREE
# 20/50...	I feel little concern for others.: DISAGREE
# 21/50...	I am interested in people.: SOMEWHAT AGREE
# 22/50...	I insult people.: DISAGREE
# 23/50...	I sympathize with others' feelings.: AGREE
# 24/50...	I am not interested in other people's problems.: DISAGREE
# 25/50...	I have a soft heart.: SOMEWHAT AGREE
# 26/50...	I am not really interested in others.: DISAGREE
# 27/50...	I take time out for others.: AGREE
# 28/50...	I feel others' emotions.: SOMEWHAT AGREE
# 29/50...	I make people feel at ease.: SOMEWHAT AGREE
# 30/50...	I am always prepared.: SOMEWHAT DISAGREE
# 31/50...	I leave my belongings around.: DISAGREE
# 32/50...	I pay attention to details.: SOMEWHAT AGREE
# 33/50...	I make a mess of things.: DISAGREE
# 34/50...	I get chores done right away.: SOMEWHAT DISAGREE
# 35/50...	I often forget to put things back in their proper place.: AGREE
# 36/50...	I like order.: SOMEWHAT AGREE
# 37/50...	I shirk my duties.: DISAGREE
# 38/50...	I follow a schedule.: SOMEWHAT DISAGREE
# 39/50...	I am exacting in my work.: SOMEWHAT AGREE
# 40/50...	I have a rich vocabulary.: SOMEWHAT AGREE
# 41/50...	I have difficulty understanding abstract ideas.: DISAGREE
# 42/50...	I have a vivid imagination.: SOMEWHAT AGREE
# 43/50...	I am not interested in abstract ideas.: DISAGREE
# 44/50...	I have excellent ideas.: SOMEWHAT AGREE
# 45/50...	I do not have a good imagination.: DISAGREE
# 46/50...	I am quick to understand things.: AGREE
# 47/50...	I use difficult words.: DISAGREE
# 48/50...	I spend time reflecting on things.: SOMEWHAT AGREE
# 49/50...	I am full of ideas.: SOMEWHAT AGREE
# batch/queue/eli-pers-0_llama3-70b_V7_2.json took 1017.681s
# brikasutils.quickCSV: Saved 14 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-0_llama3-70b_V7_2. Stauts: OK
# [15/90] Running eli-kano-4000_llama3-8b_V7_0.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I CAN TOLERATE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I DISLIKE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I CAN TOLERATE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I EXPECT IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I EXPECT IT
# 10/40...	What would you say if the game had realistic game physics?: I LIKE IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I EXPECT IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I LIKE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I DISLIKE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I LIKE IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I EXPECT IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I LIKE IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I CAN TOLERATE IT
# 18/40...	What would you say if the game had cutscenes?: I EXPECT IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I EXPECT IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I EXPECT IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I CAN TOLERATE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I EXPECT IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I LIKE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I DISLIKE IT
# 26/40...	What would you say if the game had realistic graphics?: I EXPECT IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I EXPECT IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I LIKE IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I DISLIKE IT
# 30/40...	What would you say if the game contained violent elements?: I DISLIKE IT
# 31/40...	What would you say if the game contained NO violent elements?: I LIKE IT
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I LIKE IT
# 37/40...	What would you say if the game did NOT have quests?: I EXPECT IT
# 38/40...	What would you say if the game had a clear ending or goal?: I LIKE IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/eli-kano-4000_llama3-8b_V7_0.json took 127.979s
# brikasutils.quickCSV: Saved 15 as batch/run_reports/uniform_V7.csv
# Processed eli-kano-4000_llama3-8b_V7_0. Stauts: OK
# [16/90] Running airidas-kano-4000_llama3-8b_V7_0.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I CAN TOLERATE IT
# ...
# 30/40...	What would you say if the game contained violent elements?: I DISLIKE IT
# 31/40...	What would you say if the game contained NO violent elements?: I LIKE IT
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I LIKE IT
# 37/40...	What would you say if the game did NOT have quests?: I LIKE IT
# 38/40...	What would you say if the game had a clear ending or goal?: I LIKE IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/airidas-kano-static-7500_llama3-8b_V8_0.json took 21.65s
# brikasutils.quickCSV: Saved 232 as batch/run_reports/uniform_V7.csv
# Processed airidas-kano-static-7500_llama3-8b_V8_0. Stauts: OK
# [233/236] Running eli-kano-static-7500_llama3-8b_V8_1.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I DISLIKE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I DISLIKE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I DISLIKE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I LIKE IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I AM NEUTRAL
# 10/40...	What would you say if the game had realistic game physics?: I LIKE IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I EXPECT IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I LIKE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I DISLIKE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I LIKE IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I DISLIKE IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I LIKE IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I EXPECT IT
# 18/40...	What would you say if the game had cutscenes?: I LIKE IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I CAN TOLERATE IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I LIKE IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I LIKE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I LIKE IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I CAN TOLERATE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I DISLIKE IT
# 26/40...	What would you say if the game had realistic graphics?: I LIKE IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I EXPECT IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I LIKE IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I DISLIKE IT
# 30/40...	What would you say if the game contained violent elements?: I EXPECT IT
# 31/40...	What would you say if the game contained NO violent elements?: I LIKE IT
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I LIKE IT
# 37/40...	What would you say if the game did NOT have quests?: I LIKE IT
# 38/40...	What would you say if the game had a clear ending or goal?: I LIKE IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/eli-kano-static-7500_llama3-8b_V8_1.json took 12.586s
# brikasutils.quickCSV: Saved 233 as batch/run_reports/uniform_V7.csv
# Processed eli-kano-static-7500_llama3-8b_V8_1. Stauts: OK
# [234/236] Running airidas-kano-static-0_llama3-70b_V8_0.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I EXPECT IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I CAN TOLERATE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I DISLIKE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I DISLIKE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I CAN TOLERATE IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I CAN TOLERATE IT
# 10/40...	What would you say if the game had realistic game physics?: I EXPECT IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I CAN TOLERATE IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I LIKE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I DISLIKE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I EXPECT IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I CAN TOLERATE IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I EXPECT IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I CAN TOLERATE IT
# 18/40...	What would you say if the game had cutscenes?: I EXPECT IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I CAN TOLERATE IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I LIKE IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I CAN TOLERATE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I EXPECT IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I CAN TOLERATE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I CAN TOLERATE IT
# 26/40...	What would you say if the game had realistic graphics?: I EXPECT IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I CAN TOLERATE IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I EXPECT IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I CAN TOLERATE IT
# 30/40...	What would you say if the game contained violent elements?: I CAN TOLERATE IT
# 31/40...	What would you say if the game contained NO violent elements?: I EXPECT IT
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I EXPECT IT
# 37/40...	What would you say if the game did NOT have quests?: I CAN TOLERATE IT
# 38/40...	What would you say if the game had a clear ending or goal?: I EXPECT IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/airidas-kano-static-0_llama3-70b_V8_0.json took 127.597s
# brikasutils.quickCSV: Saved 234 as batch/run_reports/uniform_V7.csv
# Processed airidas-kano-static-0_llama3-70b_V8_0. Stauts: OK
# [235/236] Running eli-pers-static-0_mixtral-8x22b_V8_1.json from queue.
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
# 0/50...	I am the life of the party.:  Somewhat Agree
# 1/50...	I don't talk a lot.:  Somewhat Disagree
# 2/50...	I feel comfortable around people.:  Somewhat Agree
# 3/50...	I keep in the background.:  Somewhat Disagree
# 4/50...	I start conversations.:  Somewhat Agree
# 5/50...	I have little to say.:  The persona chooses: SOMEWHAT DISAGREE
# 6/50...	I talk to a lot of different people at parties.:  Somewhat Agree
# 7/50...	I don't like to draw attention to myself.:  Somewhat Agree
# 8/50...	I don't mind being the center of attention.:  Somewhat Disagree
# 9/50...	I am quiet around strangers.:  Somewhat Agree
# 10/50...	I get stressed out easily.:  Somewhat Disagree
# 11/50...	I am relaxed most of the time.:  Somewhat Agree
# 12/50...	I worry about things.:  Somewhat Agree
# 13/50...	I seldom feel blue.:  Somewhat Agree
# 14/50...	I am easily disturbed.:  Somewhat Disagree
# 15/50...	I get upset easily.:  Somewhat Disagree
# 16/50...	I change my mood a lot.:  Somewhat Agree
# 17/50...	I have frequent mood swings.:  Somewhat Agree
# 18/50...	I get irritated easily.:  Somewhat Disagree
# 19/50...	I often feel blue.:  SOMEWHAT DISAGREE
# 20/50...	I feel little concern for others.:  Somewhat Disagree
# 21/50...	I am interested in people.:  Somewhat Agree
# 22/50...	I insult people.:  Somewhat Disagree
# 23/50...	I sympathize with others' feelings.:  AGREE
# 24/50...	I am not interested in other people's problems.:  Somewhat Disagree
# 25/50...	I have a soft heart.:  The persona chooses: **AGREE.**
# 26/50...	I am not really interested in others.:  SOMEWHAT DISAGREE
# 27/50...	I take time out for others.:  Agree
# 28/50...	I feel others' emotions.:  Somewhat Agree
# 29/50...	I make people feel at ease.:  AGREE
# 30/50...	I am always prepared.:  Somewhat Agree
# 31/50...	I leave my belongings around.:  Somewhat Agree
# 32/50...	I pay attention to details.:  AGREE
# 33/50...	I make a mess of things.:  Somewhat Disagree
# 34/50...	I get chores done right away.:  Somewhat disagree
# 35/50...	I often forget to put things back in their proper place.:  Somewhat Agree
# 36/50...	I like order.:  Somewhat Agree
# 37/50...	I shirk my duties.:  Somewhat Disagree
# 38/50...	I follow a schedule.:  Somewhat Disagree
# 39/50...	I am exacting in my work.:  Somewhat Agree
# 40/50...	I have a rich vocabulary.:  Somewhat Agree
# 41/50...	I have difficulty understanding abstract ideas.:  Neutral
# 42/50...	I have a vivid imagination.:  Somewhat Agree
# 43/50...	I am not interested in abstract ideas.:  Somewhat Disagree
# 44/50...	I have excellent ideas.:  Somewhat Agree
# 45/50...	I do not have a good imagination.:  Somewhat Disagree
# 46/50...	I am quick to understand things.:  Agree
# 47/50...	I use difficult words.:  Somewhat Disagree
# 48/50...	I spend time reflecting on things.:  Somewhat Agree
# 49/50...	I am full of ideas.:  Somewhat Agree
# batch/queue/eli-pers-static-0_mixtral-8x22b_V8_1.json took 144.137s
# brikasutils.quickCSV: Saved 235 as batch/run_reports/uniform_V7.csv
# Processed eli-pers-static-0_mixtral-8x22b_V8_1. Stauts: OK
# [236/236] Running eli-kano-static-4000_llama3-8b_V8_2.json from queue.
# Using default Kano Survey CSV file: surveys/survey_kano-model.csv
# 0/40...	What would you say if there were options to design your own avatar?: I LIKE IT
# 1/40...	What would you say if there were NO options to design your own avatar?: I DISLIKE IT
# 2/40...	What would you say if the game had the option to save the game at any time?: I LIKE IT
# 3/40...	What would you say if the game did NOT have the option to save the game at any time?: I CAN TOLERATE IT
# 4/40...	What would you say if the game has good graphics?: I LIKE IT
# 5/40...	What would you say if the game had NO good graphics, or rather poor graphics?: I CAN TOLERATE IT
# 6/40...	What would you say if the game had an exciting storyline?: I LIKE IT
# 7/40...	What would you say if the game did NOT have an exciting storyline?: I EXPECT IT
# 8/40...	What would you say if there were rewards such as extra points, in-game currency or coins in the game?: I LIKE IT
# 9/40...	What would you say if there were NO rewards such as extra points, in-game currency or coins in the game?: I DISLIKE IT
# 10/40...	What would you say if the game had realistic game physics?: I LIKE IT
# 11/40...	What would you say if the game does NOT have realistic physics?: I CAN TOLERATE IT
# 12/40...	What would you say if the game had a relaxed flow rather than being very exciting?: I LIKE IT
# 13/40...	What would you say if the game DON'T have a relaxed flow?: I CAN TOLERATE IT
# 14/40...	What would you say if the game had a multiplayer mode?: I EXPECT IT
# 15/40...	What would you say if the game does NOT have multiplayer mode?: I EXPECT IT
# 16/40...	What would you say if you can loot defeated enemies in the game?: I LIKE IT
# 17/40...	What would you say if you CANNOT loot defeated enemies in the game?: I DISLIKE IT
# 18/40...	What would you say if the game had cutscenes?: I LIKE IT
# 19/40...	What would you say if the game DIDN'T have cutscenes?: I EXPECT IT
# 20/40...	What would you say if the game had more and increasingly difficult levels?: I LIKE IT
# 21/40...	What would you say if the game had NO levels, or the difficulty didn't increase?: I CAN TOLERATE IT
# 22/40...	What would you say if the game had a high score table or hall of fame?: I LIKE IT
# 23/40...	What would you say if the game does NOT have a high score table or hall of fame?: I CAN TOLERATE IT
# 24/40...	What would you say if the game contains role-playing elements?: I LIKE IT
# 25/40...	What would you say if the game contained NO role-playing elements?: I EXPECT IT
# 26/40...	What would you say if the game had realistic graphics?: I EXPECT IT
# 27/40...	What would you say if the game DON'T have realistic graphics?: I EXPECT IT
# 28/40...	What would you say if the game offered the opportunity to level up the character?: I LIKE IT
# 29/40...	What would you say if the game does NOT provide a way to level up the character?: I DISLIKE IT
# 30/40...	What would you say if the game contained violent elements?: I EXPECT IT
# 31/40...	What would you say if the game contained NO violent elements?: I LIKE IT
# 32/40...	What would you say if the game gave you creative freedom?: I LIKE IT
# 33/40...	What would you say if the game DIDN'T give you creative freedom?: I DISLIKE IT
# 34/40...	What would you say if the game had a compelling plot or narrative?: I LIKE IT
# 35/40...	What would you say if the game DIDN'T have a compelling plot or narrative?: I CAN TOLERATE IT
# 36/40...	What would you say if the game had quests?: I LIKE IT
# 37/40...	What would you say if the game did NOT have quests?: I EXPECT IT
# 38/40...	What would you say if the game had a clear ending or goal?: I LIKE IT
# 39/40...	What would you say if the game does NOT have an ending or clear goal?: I CAN TOLERATE IT
# batch/queue/eli-kano-static-4000_llama3-8b_V8_2.json took 18.055s
# brikasutils.quickCSV: Saved 236 as batch/run_reports/uniform_V7.csv
# Processed eli-kano-static-4000_llama3-8b_V8_2. Stauts: OK
# Total execution time 99386.237s

# %%
display(df)
display(survey.PersonalitySurvey().df)
# Out:
#                                              question              answer
# 0                         I am the life of the party.   SOMEWHAT DISAGREE
# 1                                 I don't talk a lot.      SOMEWHAT AGREE
# 2                   I feel comfortable around people.   SOMEWHAT DISAGREE
# 3                           I keep in the background.      SOMEWHAT AGREE
# 4                              I start conversations.      SOMEWHAT AGREE
# 5                               I have little to say.   SOMEWHAT DISAGREE
# 6     I talk to a lot of different people at parties.      SOMEWHAT AGREE
# 7           I don't like to draw attention to myself.   SOMEWHAT DISAGREE
# 8         I don't mind being the center of attention.  SOMEWHAT AGREEMENT
# 9                        I am quiet around strangers.  SOMEWHAT AGREEMENT
# 10                         I get stressed out easily.   SOMEWHAT DISAGREE
# 11                     I am relaxed most of the time.      SOMEWHAT AGREE
# 12                              I worry about things.   SOMEWHAT DISAGREE
# 13                                I seldom feel blue.   SOMEWHAT DISAGREE
# 14                             I am easily disturbed.   SOMEWHAT DISAGREE
# 15                                I get upset easily.   SOMEWHAT DISAGREE
# 16                            I change my mood a lot.   SOMEWHAT DISAGREE
# 17                       I have frequent mood swings.   SOMEWHAT DISAGREE
# 18                            I get irritated easily.   SOMEWHAT DISAGREE
# 19                                 I often feel blue.   SOMEWHAT DISAGREE
# 20                  I feel little concern for others.   SOMEWHAT DISAGREE
# 21                         I am interested in people.      SOMEWHAT AGREE
# 22                                   I insult people.   SOMEWHAT DISAGREE
# 23                I sympathize with others' feelings.      SOMEWHAT AGREE
# 24    I am not interested in other people's problems.   SOMEWHAT DISAGREE
# 25                               I have a soft heart.      SOMEWHAT AGREE
# 26              I am not really interested in others.   SOMEWHAT DISAGREE
# 27                        I take time out for others.      SOMEWHAT AGREE
# 28                           I feel others' emotions.      SOMEWHAT AGREE
# 29                        I make people feel at ease.      SOMEWHAT AGREE
# 30                              I am always prepared.      SOMEWHAT AGREE
# 31                      I leave my belongings around.   SOMEWHAT DISAGREE
# 32                        I pay attention to details.      SOMEWHAT AGREE
# 33                           I make a mess of things.   SOMEWHAT DISAGREE
# 34                      I get chores done right away.     SOMEWHAT AGREES
# 35  I often forget to put things back in their pro...   SOMEWHAT DISAGREE
# 36                                      I like order.      SOMEWHAT AGREE
# 37                                 I shirk my duties.   SOMEWHAT DISAGREE
# 38                               I follow a schedule.      SOMEWHAT AGREE
# 39                          I am exacting in my work.   SOMEWHAT DISAGREE
# 40                          I have a rich vocabulary.      SOMEWHAT AGREE
# 41    I have difficulty understanding abstract ideas.   SOMEWHAT DISAGREE
# 42                        I have a vivid imagination.      SOMEWHAT AGREE
# 43             I am not interested in abstract ideas.   SOMEWHAT DISAGREE
# 44                            I have excellent ideas.      SOMEWHAT AGREE
# 45                  I do not have a good imagination.   SOMEWHAT DISAGREE
# 46                   I am quick to understand things.      SOMEWHAT AGREE
# 47                             I use difficult words.   SOMEWHAT DISAGREE
# 48                 I spend time reflecting on things.      SOMEWHAT AGREE
# 49                                I am full of ideas.      SOMEWHAT AGREE
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv
#                                              question  airidas  elias  \
# 0                         I am the life of the party.        3      3
# 1                                 I don't talk a lot.        2      2
# 2                   I feel comfortable around people.        4      4
# 3                           I keep in the background.        2      4
# 4                              I start conversations.        4      3
# 5                               I have little to say.        1      1
# 6     I talk to a lot of different people at parties.        5      4
# 7           I don't like to draw attention to myself.        2      3
# 8         I don't mind being the center of attention.        4      1
# 9                        I am quiet around strangers.        1      4
# 10                         I get stressed out easily.        4      3
# 11                     I am relaxed most of the time.        1      4
# 12                              I worry about things.        3      3
# 13                                I seldom feel blue.        3      3
# 14                             I am easily disturbed.        1      5
# 15                                I get upset easily.        2      2
# 16                            I change my mood a lot.        4      1
# 17                       I have frequent mood swings.        4      2
# 18                            I get irritated easily.        3      3
# 19                                 I often feel blue.        1      3
# 20                  I feel little concern for others.        2      2
# 21                         I am interested in people.        4      5
# 22                                   I insult people.        1      1
# 23                I sympathize with others' feelings.        4      4
# 24    I am not interested in other people's problems.        1      4
# 25                               I have a soft heart.        4      5
# 26              I am not really interested in others.        4      2
# 27                        I take time out for others.        2      5
# 28                           I feel others' emotions.        2      4
# 29                        I make people feel at ease.        2      4
# 30                              I am always prepared.        4      1
# 31                      I leave my belongings around.        2      5
# 32                        I pay attention to details.        2      3
# 33                           I make a mess of things.        2      4
# 34                      I get chores done right away.        1      2
# 35  I often forget to put things back in their pro...        2      2
# 36                                      I like order.        4      4
# 37                                 I shirk my duties.        2      1
# 38                               I follow a schedule.        4      2
# 39                          I am exacting in my work.        3      5
# 40                          I have a rich vocabulary.        3      4
# 41    I have difficulty understanding abstract ideas.        1      1
# 42                        I have a vivid imagination.        5      5
# 43             I am not interested in abstract ideas.        2      1
# 44                            I have excellent ideas.        5      4
# 45                  I do not have a good imagination.        1      1
# 46                   I am quick to understand things.        5      5
# 47                             I use difficult words.        1      4
# 48                 I spend time reflecting on things.        5      5
# 49                                I am full of ideas.        5      5
#
#                                      format category  \
# 0   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT1
# 1   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT2
# 2   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT3
# 3   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT4
# 4   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT5
# 5   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT6
# 6   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT7
# 7   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT8
# 8   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EXT9
# 9   A (1-5: 1=Disagree, 3=Neutral, 5=Agree)    EXT10
# 10  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST1
# 11  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST2
# 12  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST3
# 13  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST4
# 14  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST5
# 15  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST6
# 16  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST7
# 17  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST8
# 18  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     EST9
# 19  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)    EST10
# 20  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR1
# 21  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR2
# 22  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR3
# 23  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR4
# 24  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR5
# 25  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR6
# 26  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR7
# 27  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR8
# 28  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     AGR9
# 29  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)    AGR10
# 30  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN1
# 31  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN2
# 32  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN3
# 33  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN4
# 34  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN5
# 35  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN6
# 36  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN7
# 37  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN8
# 38  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     CSN9
# 39  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)    CSN10
# 40  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN1
# 41  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN2
# 42  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN3
# 43  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN4
# 44  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN5
# 45  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN6
# 46  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN7
# 47  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN8
# 48  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)     OPN9
# 49  A (1-5: 1=Disagree, 3=Neutral, 5=Agree)    OPN10
#
#                                   retrieval_1
# 0           engaged or not engaged in parties
# 1                      talking or not talking
# 2         comfort or discomfort around people
# 3    staying or not staying in the background
# 4      starting or not starting conversations
# 5               having little or a lot to say
# 6   talking to a lot or few people at parties
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11                                        NaN
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                        NaN
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN

# %% [markdown]
# ## Run Live simulation (not batch)

# %%
# load json file to dict
with open("batch/prompts/personality_batch-B_8k-dynamic_prompts.json", "r") as read_file:
    pre_final_prompts = json.load(read_file)

# Setup for below
SETTINGS = {
     "model": "llama3", # mixtral, command-r-plus:104b-q2_K
     "stream": True,
    #  "format": "json",
     # "temperature": 0.5,
}
##################################
SIM_ID = f"eli-pers_8k-dynamic_llama3-7_json-test"
save = f"{SETTINGS['model']}_{SIM_ID}"
LIMIT = None # For testing purposes. Set to NONE to run all
AUTO_INFO = {
    "date": bu.get_timestamp(),
    # "EMBEDDING_NAMEID": EMBEDDING_NAMEID,
    # "RETRIEVAL_PROMPT": RETRIEVAL_PROMPT,
    # "CHUNKS_COUNT_IN_CTX": CHUNKS_COUNT_IN_CTX,
    # "survey_type": str(type(surv)),
    # "prompt_count": min(len(final_prompts), LIMIT) if LIMIT != None else len(final_prompts),
    # "avg_tokens_in_prompt": round(prompt_info["total_all_prompt_tokens"]/len(final_prompts)),
}
client = OpenAI(
    base_url = 'http://localhost:11434/v1',
    api_key='ollama', # required, but unused
)
##################################

# %%
###########################################
##### ==== THE FUNCTIONAL 1!!!! ===== #####
###########################################
completions = []
l = len(final_prompts)
timer = bu.Benchmarker()
for i, (prompt, question) in enumerate(list(zip(final_prompts, surv.questions))):
    if LIMIT != None and i > LIMIT:
        break
    timer.mark()
    print(f"{i}/{l}...", end="\t") # Print progress
    # Send the Request    
    full_response = client.chat.completions.create(
        model=SETTINGS["model"],
        messages=prompt,
        # timeout=120,
        # temperature=SETTINGS["temperature"],
    )
    r = full_response.choices[0].message.content
    completions.append({'question': question, 'answer': r})
    print(f"{question}: {r}")

# Save results
df = pd.DataFrame(completions)
df.to_csv(f"simulations/{SIM_ID}_simulation.csv", index=False)
bu.quickJSON(final_prompts, f"ignorefolder/{SIM_ID}_prompts.json")
bu.quickJSON({"settings": SETTINGS, "info": AUTO_INFO}, f"simulations/{SIM_ID}_info.json")
