# %% [markdown]
# ## Setup libs

# %%
import importlib
from tools import brikasutils as bu
from tools import shared_utils as utils 
from tools.shared_utils import systemMsg, userMsg, assistantMsg
from tools import survey, persona
[importlib.reload(m) for m in [persona, survey, utils, bu]]

import ollama, os, re, time, json
import numpy as np
from numpy.linalg import norm
import pandas as pd
from typing import List
from openai import OpenAI

# %% [markdown]
# # **Analysis**

# %% [markdown]
# ### Batch analysis

# %%
def see_if_column_valid(column_name, df, msg="Verification failed for"):
    dff = df[df[column_name].isna()]
    dfff = dff.groupby("sim_signature").apply(lambda x: x[x['run_number'] == 1], include_groups=False)
    print(f"{msg}: {len(dff)} ({len(dfff)} unique)")
    return dfff

MOST_IMPORTANT_COLUMNS = ['sim_signature', 'run_number', "model", "survey_type", "base_sim_signature", "SUBJECT"]

# %%
# Index all simulation files
SIMULATIONS_DIR = "analysis/sims-final-2" #simulations-v2-tt

sim_runs = []
for root, dirs, files in os.walk(SIMULATIONS_DIR):
    for file in files:
        if file.split(".")[1] != "json":
            print(f"Invalid file (all must be json) {sim_run['path']}")

        sim_run = {}
        sim_run["SIMULATION_ID"] = file.split(".")[0]
        sim_run["path"] = os.path.join(root, file)
        with open(sim_run["path"], 'r') as f:
            sim = json.load(f)
        sim_run.update(sim["info"]["info"])
        sim_run.update(sim["info"]["settings"])
        sim_runs.append(sim_run)

df = pd.DataFrame(sim_runs)
df = df.dropna(axis=1, how='all')
print(f"Loaded {len(df)} simulation files")
# Out:
# Loaded 234 simulation files

# %% [markdown]
# ### Infer/Get Needed Data

# %%
def infer_survey_type(row):
    if "survey_type" in row and not pd.isna(row["survey_type"]):
        if row["survey_type"] == "KanoSurvey":
            return "KanoSurvey"
        elif row["survey_type"] == "PersonalitySurvey":
            return "PersonalitySurvey"
        else:
            print("Unknown survey type" + row["survey_type"])

    if "prompt_count" in row and not pd.isna(row["prompt_count"]):
        if row["prompt_count"] == 50:
            return "PersonalitySurvey"
        elif row["prompt_count"] == 40:
            return "KanoSurvey"
        else:
            print("Unknown prompt count" + row["prompt_count"])

    return None

df["survey_type"] = df.apply(infer_survey_type, axis=1) 
df["survey_type"].value_counts()

# extract_run_number
def extract_run_number(sim_id):
    try:
        parts = sim_id.rsplit('_', 1)  # Attempt to split by the last underscore
        if len(parts) == 2:  # Check if the split was successful
            return pd.Series([parts[0], int(parts[-1])])
        else:
            print(f"Error while processing {sim_id}")
            return pd.Series([pd.NA, pd.NA])  # Return None for last_number if split fails
         
    except Exception as e:  # Generic exception handling
        print(f"Error while processing {sim_id}")
        return pd.Series([pd.NA, pd.NA])

df[['sim_signature', 'run_number']] = df['SIMULATION_ID'].apply(extract_run_number)

# %%
# infer_if_simulation_is_base
def infer_if_simulation_is_base(row):
    if row["sim_signature"][:4] == "base":
        return True
    return False
    
df["is_base"] = df.apply(infer_if_simulation_is_base, axis=1)

# Below: Vanity Print
dff = df[df["is_base"] == True]
dff = dff.sort_values(by=['sim_signature', 'run_number'])
dff = dff.dropna(axis=1, how='all')
dfff = dff.groupby("sim_signature").apply(lambda x: x[x['run_number'] == 1], include_groups=False)
print(f"Found {len(dff)} ({len(dfff)} unique) base simulations")
# Out:
# Found 12 (4 unique) base simulations

# %%
# Map simulations to their base
def map_simulation_to_base(row):
    if row["is_base"] == True:
        return "(base)"
    if row["survey_type"] == "KanoSurvey" and row["model"] == "gpt-3.5-turbo":
        return "base_kano_v2_gpt35"

    if row["survey_type"] == "PersonalitySurvey" and row["model"] == "gpt-3.5-turbo":
        return "base_personality_v2_gpt35"

    if row["survey_type"] == "KanoSurvey" and row["model"] == "llama3:70b":
        return "base_kano_v2_llama3"

    if row["survey_type"] == "PersonalitySurvey" and row["model"] == "llama3:70b":
        return "base_personality_v2_llama3"
    
    return pd.NA
    
df["base_sim_signature"] = df.apply(map_simulation_to_base, axis=1)
dff = see_if_column_valid("base_sim_signature", df, "Missing mappings")
if len(dff) == 0:
    print("All mappings are valid")
else:
    print("Not all mappings are valid. See the missing mappings below")
    display(dff)

def infer_subject(row):
    if row["is_base"]:
        return "(base)"
    if "SUBJECT" in row and pd.notna(row["SUBJECT"]):
        if row["SUBJECT"] == "airidas" or row["SUBJECT"] == "Airidas" or row["SUBJECT"] == "airi":
            return "airidas"
        if row["SUBJECT"] == "elias" or row["SUBJECT"] == "eli":
            return "elias"
        print(f"Unknown subject: {row['SUBJECT']}")
        return pd.NA
    if "subject" in row and pd.notna(row["subject"]):
        if row["subject"] == "airidas" or row["subject"] == "Airidas" or row["subject"] == "airi":
            return "airidas"
        if row["subject"] == "elias" or row["subject"] == "eli":
            return "elias"
        print(f"Unknown subject: {row['subject']}")
        return pd.NA
    if row["sim_signature"][:4] == "airi":
        return "airidas"
    if row["sim_signature"][:3] == "eli":
        return "elias"
    return pd.NA

df["SUBJECT"] = df.apply(infer_subject, axis=1)
dff = see_if_column_valid("SUBJECT", df, "Missing subjects")
if len(dff) == 0:
    print("All subjects are valid")
else:
    display(dff)

df = utils.bring_to_front_important_columns(df, MOST_IMPORTANT_COLUMNS)
# Out:
# Missing mappings: 144 (48 unique)
# Not all mappings are valid. See the missing mappings below
#                                                                                      SIMULATION_ID  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93   eli-kano-dynamic-25-01-19_V5_llama3_8b_schema_1
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140  eli-kano-dynamic-25-03-19_V5_llama3_8b_schema_1
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134  eli-kano-dynamic-25-05-19_V5_llama3_8b_schema_1
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79   eli-kano-dynamic-25-10-19_V5_llama3_8b_schema_1
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41   eli-kano-dynamic-50-01-09_V5_llama3_8b_schema_1
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99   eli-kano-dynamic-50-03-09_V5_llama3_8b_schema_1
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174  eli-kano-dynamic-50-05-09_V5_llama3_8b_schema_1
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32   eli-kano-dynamic-50-10-09_V5_llama3_8b_schema_1
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116  eli-kano-dynamic-75-01-05_V5_llama3_8b_schema_1
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19   eli-kano-dynamic-75-03-05_V5_llama3_8b_schema_1
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75   eli-kano-dynamic-75-05-05_V5_llama3_8b_schema_1
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130  eli-kano-dynamic-75-10-05_V5_llama3_8b_schema_1
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25    eli-kano-static-25-01-19_V5_llama3_8b_schema_1
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119   eli-kano-static-25-03-19_V5_llama3_8b_schema_1
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158   eli-kano-static-25-05-19_V5_llama3_8b_schema_1
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6     eli-kano-static-25-10-19_V5_llama3_8b_schema_1
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63    eli-kano-static-50-01-09_V5_llama3_8b_schema_1
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164   eli-kano-static-50-03-09_V5_llama3_8b_schema_1
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107   eli-kano-static-50-05-09_V5_llama3_8b_schema_1
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57    eli-kano-static-50-10-09_V5_llama3_8b_schema_1
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137   eli-kano-static-75-01-05_V5_llama3_8b_schema_1
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88    eli-kano-static-75-03-05_V5_llama3_8b_schema_1
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1     eli-kano-static-75-05-05_V5_llama3_8b_schema_1
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153   eli-kano-static-75-10-05_V5_llama3_8b_schema_1
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31   eli-pers-dynamic-25-01-19_V5_llama3_8b_schema_1
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112  eli-pers-dynamic-25-03-19_V5_llama3_8b_schema_1
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161  eli-pers-dynamic-25-05-19_V5_llama3_8b_schema_1
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42   eli-pers-dynamic-25-10-19_V5_llama3_8b_schema_1
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80   eli-pers-dynamic-50-01-09_V5_llama3_8b_schema_1
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148  eli-pers-dynamic-50-03-09_V5_llama3_8b_schema_1
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122  eli-pers-dynamic-50-05-09_V5_llama3_8b_schema_1
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92   eli-pers-dynamic-50-10-09_V5_llama3_8b_schema_1
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179  eli-pers-dynamic-75-01-05_V5_llama3_8b_schema_1
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53   eli-pers-dynamic-75-03-05_V5_llama3_8b_schema_1
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46   eli-pers-dynamic-75-05-05_V5_llama3_8b_schema_1
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168  eli-pers-dynamic-75-10-05_V5_llama3_8b_schema_1
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52    eli-pers-static-25-01-19_V5_llama3_8b_schema_1
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178   eli-pers-static-25-03-19_V5_llama3_8b_schema_1
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94    eli-pers-static-25-05-19_V5_llama3_8b_schema_1
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68    eli-pers-static-25-10-19_V5_llama3_8b_schema_1
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11    eli-pers-static-50-01-09_V5_llama3_8b_schema_1
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132   eli-pers-static-50-03-09_V5_llama3_8b_schema_1
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146   eli-pers-static-50-05-09_V5_llama3_8b_schema_1
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16    eli-pers-static-50-10-09_V5_llama3_8b_schema_1
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114   eli-pers-static-75-01-05_V5_llama3_8b_schema_1
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34    eli-pers-static-75-03-05_V5_llama3_8b_schema_1
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71    eli-pers-static-75-05-05_V5_llama3_8b_schema_1
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96    eli-pers-static-75-10-05_V5_llama3_8b_schema_1
#
#                                                                                                 path  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93   analysis/sims-final-1/eli-kano-dynamic-25-01-1...
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140  analysis/sims-final-1/eli-kano-dynamic-25-03-1...
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134  analysis/sims-final-1/eli-kano-dynamic-25-05-1...
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79   analysis/sims-final-1/eli-kano-dynamic-25-10-1...
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41   analysis/sims-final-1/eli-kano-dynamic-50-01-0...
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99   analysis/sims-final-1/eli-kano-dynamic-50-03-0...
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174  analysis/sims-final-1/eli-kano-dynamic-50-05-0...
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32   analysis/sims-final-1/eli-kano-dynamic-50-10-0...
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116  analysis/sims-final-1/eli-kano-dynamic-75-01-0...
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19   analysis/sims-final-1/eli-kano-dynamic-75-03-0...
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75   analysis/sims-final-1/eli-kano-dynamic-75-05-0...
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130  analysis/sims-final-1/eli-kano-dynamic-75-10-0...
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25   analysis/sims-final-1/eli-kano-static-25-01-19...
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119  analysis/sims-final-1/eli-kano-static-25-03-19...
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158  analysis/sims-final-1/eli-kano-static-25-05-19...
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6    analysis/sims-final-1/eli-kano-static-25-10-19...
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63   analysis/sims-final-1/eli-kano-static-50-01-09...
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164  analysis/sims-final-1/eli-kano-static-50-03-09...
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107  analysis/sims-final-1/eli-kano-static-50-05-09...
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57   analysis/sims-final-1/eli-kano-static-50-10-09...
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137  analysis/sims-final-1/eli-kano-static-75-01-05...
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88   analysis/sims-final-1/eli-kano-static-75-03-05...
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1    analysis/sims-final-1/eli-kano-static-75-05-05...
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153  analysis/sims-final-1/eli-kano-static-75-10-05...
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31   analysis/sims-final-1/eli-pers-dynamic-25-01-1...
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112  analysis/sims-final-1/eli-pers-dynamic-25-03-1...
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161  analysis/sims-final-1/eli-pers-dynamic-25-05-1...
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42   analysis/sims-final-1/eli-pers-dynamic-25-10-1...
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80   analysis/sims-final-1/eli-pers-dynamic-50-01-0...
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148  analysis/sims-final-1/eli-pers-dynamic-50-03-0...
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122  analysis/sims-final-1/eli-pers-dynamic-50-05-0...
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92   analysis/sims-final-1/eli-pers-dynamic-50-10-0...
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179  analysis/sims-final-1/eli-pers-dynamic-75-01-0...
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53   analysis/sims-final-1/eli-pers-dynamic-75-03-0...
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46   analysis/sims-final-1/eli-pers-dynamic-75-05-0...
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168  analysis/sims-final-1/eli-pers-dynamic-75-10-0...
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52   analysis/sims-final-1/eli-pers-static-25-01-19...
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178  analysis/sims-final-1/eli-pers-static-25-03-19...
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94   analysis/sims-final-1/eli-pers-static-25-05-19...
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68   analysis/sims-final-1/eli-pers-static-25-10-19...
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11   analysis/sims-final-1/eli-pers-static-50-01-09...
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132  analysis/sims-final-1/eli-pers-static-50-03-09...
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146  analysis/sims-final-1/eli-pers-static-50-05-09...
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16   analysis/sims-final-1/eli-pers-static-50-10-09...
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114  analysis/sims-final-1/eli-pers-static-75-01-05...
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34   analysis/sims-final-1/eli-pers-static-75-03-05...
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71   analysis/sims-final-1/eli-pers-static-75-05-05...
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96   analysis/sims-final-1/eli-pers-static-75-10-05...
#
#                                                                 date  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93   2024-05-02_030401
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140  2024-05-02_045542
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134  2024-05-02_040519
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79   2024-05-02_032627
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41   2024-05-02_021544
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99   2024-05-02_040236
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174  2024-05-02_051701
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32   2024-05-02_022721
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116  2024-05-02_043136
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19   2024-05-02_013646
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75   2024-05-02_033514
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130  2024-05-02_040741
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25   2024-05-02_013558
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119  2024-05-02_043053
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158  2024-05-02_043359
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6    2024-05-02_014321
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63   2024-05-02_024344
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164  2024-05-02_052335
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107  2024-05-02_034643
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57   2024-05-02_025732
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137  2024-05-02_045818
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88   2024-05-02_030642
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1    2024-05-02_014857
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153  2024-05-02_044905
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31   2024-05-02_022417
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112  2024-05-02_033736
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161  2024-05-02_053510
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42   2024-05-02_021757
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80   2024-05-02_032846
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148  2024-05-02_044930
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122  2024-05-02_042212
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92   2024-05-02_030059
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179  2024-05-02_051035
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53   2024-05-02_025804
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46   2024-05-02_015437
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168  2024-05-02_052000
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52   2024-05-02_025745
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178  2024-05-02_051018
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94   2024-05-02_040453
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68   2024-05-02_024327
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11   2024-05-02_014249
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132  2024-05-02_041007
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146  2024-05-02_045222
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16   2024-05-02_013620
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114  2024-05-02_034034
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34   2024-05-02_022940
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71   2024-05-02_023942
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96   2024-05-02_035913
#
#                                                    CHUNK_SIZE  OVERLAP_SIZE  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93         25.0           1.0
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140        25.0           3.0
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134        25.0           5.0
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79         25.0          10.0
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41         50.0           1.0
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99         50.0           3.0
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174        50.0           5.0
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32         50.0          10.0
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116        75.0           1.0
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19         75.0           3.0
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75         75.0           5.0
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130        75.0          10.0
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25         25.0           1.0
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119        25.0           3.0
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158        25.0           5.0
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6          25.0          10.0
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63         50.0           1.0
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164        50.0           3.0
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107        50.0           5.0
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57         50.0          10.0
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137        75.0           1.0
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88         75.0           3.0
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1          75.0           5.0
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153        75.0          10.0
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31         25.0           1.0
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112        25.0           3.0
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161        25.0           5.0
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42         25.0          10.0
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80         50.0           1.0
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148        50.0           3.0
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122        50.0           5.0
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92         50.0          10.0
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179        75.0           1.0
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53         75.0           3.0
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46         75.0           5.0
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168        75.0          10.0
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52         25.0           1.0
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178        25.0           3.0
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94         25.0           5.0
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68         25.0          10.0
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11         50.0           1.0
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132        50.0           3.0
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146        50.0           5.0
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16         50.0          10.0
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114        75.0           1.0
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34         75.0           3.0
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71         75.0           5.0
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96         75.0          10.0
#
#                                                    tokens_in_chunks  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93           242500.0
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140          247538.0
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134          241028.0
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79           251298.0
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41           228585.0
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99           220091.0
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174          221077.0
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32           221990.0
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116          210350.0
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19           190505.0
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75           192215.0
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130          204324.0
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25             6415.0
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119            6346.0
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158            5262.0
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6              6194.0
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63             5112.0
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164            4959.0
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107            4686.0
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57             5273.0
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137            5322.0
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88             4622.0
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1              4328.0
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153            5027.0
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31           373167.0
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112          354100.0
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161          350622.0
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42           375712.0
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80           282499.0
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148          271866.0
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122          259452.0
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92           278793.0
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179          258801.0
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53           245258.0
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46           248739.0
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168          257468.0
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52             7729.0
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178            7865.0
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94             7754.0
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68             7783.0
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11             5548.0
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132            6204.0
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146            5089.0
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16             5409.0
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114            6598.0
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34             4840.0
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71             7178.0
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96             5396.0
#
#                                                    CTX_limit   model  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93      7000.0  llama3
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140     7000.0  llama3
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134     7000.0  llama3
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79      7000.0  llama3
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41      7000.0  llama3
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99      7000.0  llama3
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174     7000.0  llama3
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32      7000.0  llama3
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116     7000.0  llama3
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19      7000.0  llama3
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75      7000.0  llama3
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130     7000.0  llama3
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25      7000.0  llama3
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119     7000.0  llama3
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158     7000.0  llama3
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6       7000.0  llama3
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63      7000.0  llama3
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164     7000.0  llama3
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107     7000.0  llama3
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57      7000.0  llama3
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137     7000.0  llama3
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88      7000.0  llama3
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1       7000.0  llama3
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153     7000.0  llama3
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31      7000.0  llama3
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112     7000.0  llama3
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161     7000.0  llama3
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42      7000.0  llama3
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80      7000.0  llama3
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148     7000.0  llama3
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122     7000.0  llama3
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92      7000.0  llama3
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179     7000.0  llama3
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53      7000.0  llama3
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46      7000.0  llama3
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168     7000.0  llama3
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52      7000.0  llama3
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178     7000.0  llama3
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94      7000.0  llama3
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68      7000.0  llama3
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11      7000.0  llama3
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132     7000.0  llama3
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146     7000.0  llama3
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16      7000.0  llama3
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114     7000.0  llama3
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34      7000.0  llama3
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71      7000.0  llama3
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96      7000.0  llama3
#
#                                                   prompt method  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93    IMPERSONATE
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140   IMPERSONATE
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134   IMPERSONATE
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79    IMPERSONATE
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41    IMPERSONATE
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99    IMPERSONATE
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174   IMPERSONATE
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32    IMPERSONATE
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116   IMPERSONATE
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19    IMPERSONATE
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75    IMPERSONATE
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130   IMPERSONATE
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25    IMPERSONATE
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119   IMPERSONATE
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158   IMPERSONATE
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6     IMPERSONATE
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63    IMPERSONATE
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164   IMPERSONATE
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107   IMPERSONATE
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57    IMPERSONATE
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137   IMPERSONATE
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88    IMPERSONATE
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1     IMPERSONATE
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153   IMPERSONATE
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31    IMPERSONATE
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112   IMPERSONATE
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161   IMPERSONATE
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42    IMPERSONATE
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80    IMPERSONATE
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148   IMPERSONATE
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122   IMPERSONATE
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92    IMPERSONATE
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179   IMPERSONATE
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53    IMPERSONATE
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46    IMPERSONATE
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168   IMPERSONATE
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52    IMPERSONATE
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178   IMPERSONATE
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94    IMPERSONATE
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68    IMPERSONATE
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11    IMPERSONATE
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132   IMPERSONATE
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146   IMPERSONATE
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16    IMPERSONATE
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114   IMPERSONATE
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34    IMPERSONATE
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71    IMPERSONATE
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96    IMPERSONATE
#
#                                                   retrieval method  ...  \
# sim_signature                                                       ...
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93           dynamic  ...
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140          dynamic  ...
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134          dynamic  ...
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79           dynamic  ...
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41           dynamic  ...
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99           dynamic  ...
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174          dynamic  ...
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32           dynamic  ...
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116          dynamic  ...
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19           dynamic  ...
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75           dynamic  ...
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130          dynamic  ...
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25            static  ...
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119           static  ...
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158           static  ...
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6             static  ...
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63            static  ...
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164           static  ...
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107           static  ...
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57            static  ...
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137           static  ...
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88            static  ...
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1             static  ...
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153           static  ...
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31           dynamic  ...
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112          dynamic  ...
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161          dynamic  ...
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42           dynamic  ...
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80           dynamic  ...
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148          dynamic  ...
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122          dynamic  ...
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92           dynamic  ...
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179          dynamic  ...
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53           dynamic  ...
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46           dynamic  ...
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168          dynamic  ...
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52            static  ...
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178           static  ...
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94            static  ...
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68            static  ...
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11            static  ...
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132           static  ...
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146           static  ...
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16            static  ...
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114           static  ...
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34            static  ...
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71            static  ...
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96            static  ...
#
#                                                   timeout  note SUBJECT  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93      300   NaN     NaN
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140     300   NaN     NaN
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134     300   NaN     NaN
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79      300   NaN     NaN
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41      300   NaN     NaN
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99      300   NaN     NaN
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174     300   NaN     NaN
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32      300   NaN     NaN
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116     300   NaN     NaN
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19      300   NaN     NaN
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75      300   NaN     NaN
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130     300   NaN     NaN
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25      300   NaN     NaN
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119     300   NaN     NaN
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158     300   NaN     NaN
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6       300   NaN     NaN
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63      300   NaN     NaN
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164     300   NaN     NaN
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107     300   NaN     NaN
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57      300   NaN     NaN
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137     300   NaN     NaN
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88      300   NaN     NaN
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1       300   NaN     NaN
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153     300   NaN     NaN
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31      300   NaN     NaN
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112     300   NaN     NaN
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161     300   NaN     NaN
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42      300   NaN     NaN
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80      300   NaN     NaN
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148     300   NaN     NaN
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122     300   NaN     NaN
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92      300   NaN     NaN
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179     300   NaN     NaN
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53      300   NaN     NaN
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46      300   NaN     NaN
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168     300   NaN     NaN
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52      300   NaN     NaN
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178     300   NaN     NaN
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94      300   NaN     NaN
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68      300   NaN     NaN
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11      300   NaN     NaN
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132     300   NaN     NaN
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146     300   NaN     NaN
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16      300   NaN     NaN
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114     300   NaN     NaN
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34      300   NaN     NaN
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71      300   NaN     NaN
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96      300   NaN     NaN
#
#                                                   EMBEDDING_NAMEID  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93               NaN
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140              NaN
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134              NaN
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79               NaN
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41               NaN
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99               NaN
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174              NaN
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32               NaN
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116              NaN
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19               NaN
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75               NaN
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130              NaN
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25               NaN
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119              NaN
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158              NaN
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6                NaN
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63               NaN
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164              NaN
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107              NaN
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57               NaN
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137              NaN
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88               NaN
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1                NaN
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153              NaN
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31               NaN
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112              NaN
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161              NaN
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42               NaN
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80               NaN
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148              NaN
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122              NaN
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92               NaN
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179              NaN
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53               NaN
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46               NaN
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168              NaN
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52               NaN
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178              NaN
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94               NaN
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68               NaN
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11               NaN
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132              NaN
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146              NaN
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16               NaN
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114              NaN
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34               NaN
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71               NaN
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96               NaN
#
#                                                   RETRIEVAL_PROMPT  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93               NaN
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140              NaN
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134              NaN
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79               NaN
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41               NaN
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99               NaN
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174              NaN
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32               NaN
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116              NaN
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19               NaN
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75               NaN
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130              NaN
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25               NaN
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119              NaN
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158              NaN
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6                NaN
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63               NaN
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164              NaN
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107              NaN
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57               NaN
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137              NaN
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88               NaN
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1                NaN
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153              NaN
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31               NaN
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112              NaN
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161              NaN
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42               NaN
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80               NaN
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148              NaN
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122              NaN
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92               NaN
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179              NaN
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53               NaN
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46               NaN
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168              NaN
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52               NaN
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178              NaN
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94               NaN
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68               NaN
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11               NaN
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132              NaN
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146              NaN
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16               NaN
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114              NaN
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34               NaN
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71               NaN
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96               NaN
#
#                                                    temperature  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93           NaN
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140          NaN
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134          NaN
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79           NaN
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41           NaN
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99           NaN
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174          NaN
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32           NaN
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116          NaN
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19           NaN
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75           NaN
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130          NaN
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25           NaN
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119          NaN
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158          NaN
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6            NaN
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63           NaN
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164          NaN
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107          NaN
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57           NaN
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137          NaN
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88           NaN
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1            NaN
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153          NaN
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31           NaN
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112          NaN
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161          NaN
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42           NaN
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80           NaN
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148          NaN
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122          NaN
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92           NaN
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179          NaN
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53           NaN
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46           NaN
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168          NaN
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52           NaN
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178          NaN
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94           NaN
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68           NaN
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11           NaN
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132          NaN
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146          NaN
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16           NaN
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114          NaN
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34           NaN
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71           NaN
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96           NaN
#
#                                                          survey_type  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93          KanoSurvey
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140         KanoSurvey
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134         KanoSurvey
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79          KanoSurvey
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41          KanoSurvey
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99          KanoSurvey
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174         KanoSurvey
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32          KanoSurvey
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116         KanoSurvey
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19          KanoSurvey
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75          KanoSurvey
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130         KanoSurvey
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25          KanoSurvey
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119         KanoSurvey
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158         KanoSurvey
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6           KanoSurvey
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63          KanoSurvey
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164         KanoSurvey
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107         KanoSurvey
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57          KanoSurvey
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137         KanoSurvey
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88          KanoSurvey
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1           KanoSurvey
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153         KanoSurvey
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31   PersonalitySurvey
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112  PersonalitySurvey
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161  PersonalitySurvey
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42   PersonalitySurvey
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80   PersonalitySurvey
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148  PersonalitySurvey
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122  PersonalitySurvey
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92   PersonalitySurvey
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179  PersonalitySurvey
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53   PersonalitySurvey
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46   PersonalitySurvey
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168  PersonalitySurvey
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52   PersonalitySurvey
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178  PersonalitySurvey
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94   PersonalitySurvey
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68   PersonalitySurvey
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11   PersonalitySurvey
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132  PersonalitySurvey
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146  PersonalitySurvey
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16   PersonalitySurvey
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114  PersonalitySurvey
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34   PersonalitySurvey
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71   PersonalitySurvey
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96   PersonalitySurvey
#
#                                                    run_number  is_base  \
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93            1    False
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140           1    False
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134           1    False
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79            1    False
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41            1    False
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99            1    False
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174           1    False
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32            1    False
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116           1    False
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19            1    False
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75            1    False
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130           1    False
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25            1    False
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119           1    False
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158           1    False
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6             1    False
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63            1    False
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164           1    False
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107           1    False
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57            1    False
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137           1    False
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88            1    False
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1             1    False
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153           1    False
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31            1    False
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112           1    False
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161           1    False
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42            1    False
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80            1    False
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148           1    False
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122           1    False
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92            1    False
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179           1    False
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53            1    False
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46            1    False
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168           1    False
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52            1    False
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178           1    False
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94            1    False
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68            1    False
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11            1    False
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132           1    False
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146           1    False
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16            1    False
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114           1    False
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34            1    False
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71            1    False
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96            1    False
#
#                                                    base_sim_signature
# sim_signature
# eli-kano-dynamic-25-01-19_V5_llama3_8b_schema 93                  NaN
# eli-kano-dynamic-25-03-19_V5_llama3_8b_schema 140                 NaN
# eli-kano-dynamic-25-05-19_V5_llama3_8b_schema 134                 NaN
# eli-kano-dynamic-25-10-19_V5_llama3_8b_schema 79                  NaN
# eli-kano-dynamic-50-01-09_V5_llama3_8b_schema 41                  NaN
# eli-kano-dynamic-50-03-09_V5_llama3_8b_schema 99                  NaN
# eli-kano-dynamic-50-05-09_V5_llama3_8b_schema 174                 NaN
# eli-kano-dynamic-50-10-09_V5_llama3_8b_schema 32                  NaN
# eli-kano-dynamic-75-01-05_V5_llama3_8b_schema 116                 NaN
# eli-kano-dynamic-75-03-05_V5_llama3_8b_schema 19                  NaN
# eli-kano-dynamic-75-05-05_V5_llama3_8b_schema 75                  NaN
# eli-kano-dynamic-75-10-05_V5_llama3_8b_schema 130                 NaN
# eli-kano-static-25-01-19_V5_llama3_8b_schema  25                  NaN
# eli-kano-static-25-03-19_V5_llama3_8b_schema  119                 NaN
# eli-kano-static-25-05-19_V5_llama3_8b_schema  158                 NaN
# eli-kano-static-25-10-19_V5_llama3_8b_schema  6                   NaN
# eli-kano-static-50-01-09_V5_llama3_8b_schema  63                  NaN
# eli-kano-static-50-03-09_V5_llama3_8b_schema  164                 NaN
# eli-kano-static-50-05-09_V5_llama3_8b_schema  107                 NaN
# eli-kano-static-50-10-09_V5_llama3_8b_schema  57                  NaN
# eli-kano-static-75-01-05_V5_llama3_8b_schema  137                 NaN
# eli-kano-static-75-03-05_V5_llama3_8b_schema  88                  NaN
# eli-kano-static-75-05-05_V5_llama3_8b_schema  1                   NaN
# eli-kano-static-75-10-05_V5_llama3_8b_schema  153                 NaN
# eli-pers-dynamic-25-01-19_V5_llama3_8b_schema 31                  NaN
# eli-pers-dynamic-25-03-19_V5_llama3_8b_schema 112                 NaN
# eli-pers-dynamic-25-05-19_V5_llama3_8b_schema 161                 NaN
# eli-pers-dynamic-25-10-19_V5_llama3_8b_schema 42                  NaN
# eli-pers-dynamic-50-01-09_V5_llama3_8b_schema 80                  NaN
# eli-pers-dynamic-50-03-09_V5_llama3_8b_schema 148                 NaN
# eli-pers-dynamic-50-05-09_V5_llama3_8b_schema 122                 NaN
# eli-pers-dynamic-50-10-09_V5_llama3_8b_schema 92                  NaN
# eli-pers-dynamic-75-01-05_V5_llama3_8b_schema 179                 NaN
# eli-pers-dynamic-75-03-05_V5_llama3_8b_schema 53                  NaN
# eli-pers-dynamic-75-05-05_V5_llama3_8b_schema 46                  NaN
# eli-pers-dynamic-75-10-05_V5_llama3_8b_schema 168                 NaN
# eli-pers-static-25-01-19_V5_llama3_8b_schema  52                  NaN
# eli-pers-static-25-03-19_V5_llama3_8b_schema  178                 NaN
# eli-pers-static-25-05-19_V5_llama3_8b_schema  94                  NaN
# eli-pers-static-25-10-19_V5_llama3_8b_schema  68                  NaN
# eli-pers-static-50-01-09_V5_llama3_8b_schema  11                  NaN
# eli-pers-static-50-03-09_V5_llama3_8b_schema  132                 NaN
# eli-pers-static-50-05-09_V5_llama3_8b_schema  146                 NaN
# eli-pers-static-50-10-09_V5_llama3_8b_schema  16                  NaN
# eli-pers-static-75-01-05_V5_llama3_8b_schema  114                 NaN
# eli-pers-static-75-03-05_V5_llama3_8b_schema  34                  NaN
# eli-pers-static-75-05-05_V5_llama3_8b_schema  71                  NaN
# eli-pers-static-75-10-05_V5_llama3_8b_schema  96                  NaN
#
# [48 rows x 30 columns]
# Missing subjects: 0 (0 unique)
# All subjects are valid

# %% [markdown]
# ### Compute Scores

# %% [markdown]
# #### Setup

# %%
def get_surv_from_info(row):
    if row["survey_type"] == "KanoSurvey":
        return survey.KanoSurvey()
    elif row["survey_type"] == "PersonalitySurvey":
        return survey.PersonalitySurvey()
    else:
        raise Exception("Unknown survey type: " + row["survey_type"])

all_possible_asnwers = ["I LIKE IT", "I EXPECT IT", "I AM NEUTRAL", "I CAN TOLERATE IT", "I DISLIKE IT", "SOMEWHAT DISAGREE", "DISAGREE", "NEUTRAL", "SOMEWHAT AGREE", "AGREE"]
def extract_possible_answer(value):
    for phrase in all_possible_asnwers:
        pattern = r'(?i)' + re.escape(phrase)
        match = re.search(pattern, value)
        if match:
            return match.group()
    return value  # Return the original value if no possible answer is found

############ Invalid Answers ##################
def get_invalid_answers(value):
    if pd.isna(value):
        return ""
    elif value == "NaN":
        return ""
    elif value in all_possible_asnwers:
        return ""
    else:
        return value

def clean_simulation_QA(df) -> pd.DataFrame:
    df['answer'] = df['answer'].apply(lambda x: x.strip())
    for substr in utils.BLACKLIST_ANSWER_SUBSTRINGS:
        df['answer'] = df['answer'].apply(lambda x: re.sub(substr, "", x))
    df['answer'] = df['answer'].str.upper()
    df['answer'] = df['answer'].apply(extract_possible_answer)

    REMAP_MISSING_E = {"AGRE": "AGREE", "SOMEWHAT AGRE": "SOMEWHAT AGREE", "SOMEWHAT DISAGRE": "SOMEWHAT DISAGREE", "DISAGRE": "DISAGREE"}
    df.iloc[:, 1:] = df.iloc[:, 1:].map(lambda x: REMAP_MISSING_E.get(x, x))

    PARTIAL_MATCH_REMAP = {"SOMEWHAT AG":"SOMEWHAT AGREE" }
    df["answer"] = df["answer"].apply(
        lambda answer: next((value for key, value in PARTIAL_MATCH_REMAP.items() if key in answer), answer)
    )

    # Update isValid
    df['isValid'] = df['answer'].apply(lambda x: x in all_possible_asnwers)

    # if all values in isValid is true, drop the column, else print a message
    if not df['isValid'].all():
        print("Warning, some answers were not valid. See df['isValid']")      

    return df

# Proces simulation output
def add_airidas_and_elias_answers(df, surv) -> pd.DataFrame:
    # Add airidas and elias answers
    air = surv.test_answers["airidas"]
    eli = surv.test_answers["elias"]

    # Sanity Check
    if len(air) != len(df):
        raise Exception(f"Survey and DF length mismatch {len(air)} != {len(df)}. Suvey type: {str(type(surv))}")

    df.insert(2, "airidas", air[:len(df)])
    df.insert(3, "elias", eli[:len(df)])

    # Convert to uppercase
    if isinstance(surv, survey.KanoSurvey):
        df['answer'] = df['answer'].str.upper()
        df['airidas'] = df['airidas'].str.upper()
        df['elias'] = df['elias'].str.upper()
        
    return df

def remap_answers_to_integers(df, surv):
    # Sanity Check
    if len(surv.test_answers["airidas"]) != len(df):
        raise Exception(f"Survey and DF length mismatch {len(surv.test_answers['airidas']) } != {len(df)}. Check survey type.")

    if isinstance(surv, survey.KanoSurvey):
        remap_dict = {"I EXPECT IT": 5, "I LIKE IT": 4, "I AM NEUTRAL": 3, "I CAN TOLERATE IT": 2, "I DISLIKE IT": 1}
        df['answer'] = df['answer'].map(remap_dict)
        df['airidas'] = df['airidas'].map(remap_dict)
        df['elias'] = df['elias'].map(remap_dict)
    elif isinstance(surv, survey.PersonalitySurvey):
        remap_dict = {"AGREE": 5, "SOMEWHAT AGREE": 4, "NEUTRAL": 3, "SOMEWHAT DISAGREE": 2, "DISAGREE": 1}
        df['answer'] = df['answer'].map(remap_dict)

    return df

def evaluate_single_simulation_run(df) -> dict:
    # compute the percentage of correct answers and average loss (MAE)
    result_data = {
        "p-corr_Airidas": df['answer'].corr(df['airidas']),
        "p-corr_Elias": df['answer'].corr(df['elias']),
        # Average of absolute residuals for Airidas
        "mean_residual_Airidas": (df['answer'] - df['airidas']).abs().sum() / len(df),
        # Average of absolute residuals for Elias
        "mean_residual_Elias": (df['answer'] - df['elias']).abs().sum() / len(df),
    }
    return result_data


ADD_TO_MOST_IMPORTANT_COLUMNS = ["p-corr_Airidas", "p-corr_Elias", "mean_residual_Airidas", "mean_residual_Elias"]
for col in ADD_TO_MOST_IMPORTANT_COLUMNS:
    if col not in MOST_IMPORTANT_COLUMNS:
        MOST_IMPORTANT_COLUMNS.append(col)

# %% [markdown]
# #### Single Sim

# %%
sim_i = df.iloc[1]
print(sim_i["sim_signature"])
sim = utils.load_sim(sim_i["path"])
dfa = utils.dataframe_from_QA(sim["QA"])

surv = get_surv_from_info(sim_i)
dfa = clean_simulation_QA(dfa)
dfa = add_airidas_and_elias_answers(dfa, surv)
dfa = remap_answers_to_integers(dfa, surv)
res = evaluate_single_simulation_run(dfa)
# Out:
# <NA>
# Using default Personality Survey CSV file: surveys/survey_personality-test.csv

# %%
df
# Out:
#   sim_signature run_number                             model  \
# 0          <NA>       <NA>          command-r-plus:104b-q2_K
# 1          <NA>       <NA>          command-r-plus:104b-q2_K
# 2          <NA>       <NA>  mixtral:8x22b-instruct-v0.1-q2_K
# 3          <NA>       <NA>  mixtral:8x22b-instruct-v0.1-q2_K
# 4          <NA>       <NA>  mixtral:8x22b-instruct-v0.1-q2_K
# 5          <NA>       <NA>          command-r-plus:104b-q2_K
# 6          <NA>       <NA>          command-r-plus:104b-q2_K
# 7          <NA>       <NA>  mixtral:8x22b-instruct-v0.1-q2_K
#
#          survey_type  p-corr_Airidas  p-corr_Elias  mean_residual_Airidas  \
# 0  PersonalitySurvey           0.249         0.243                   1.20
# 1  PersonalitySurvey           0.191         0.107                   1.26
# 2  PersonalitySurvey           0.519         0.654                   1.14
# 3  PersonalitySurvey           0.409         0.476                   1.32
# 4  PersonalitySurvey           0.539         0.552                   1.14
# 5  PersonalitySurvey           0.300         0.200                   1.24
# 6  PersonalitySurvey           0.166         0.091                   1.36
# 7  PersonalitySurvey           0.474         0.524                   1.18
#
#    mean_residual_Elias                                      SIMULATION_ID  \
# 0                 1.34  eli-pers-hybrid-100-05-20_command-r-plus_104b-...
# 1                 1.40  eli-pers-dynamic-200-05-09_command-r-plus_104b...
# 2                 0.84  eli-pers-dynamic-100-05-20_mixtral_8x22b-instr...
# 3                 1.10  eli-pers-hybrid-100-05-20_mixtral_8x22b-instru...
# 4                 1.00  eli-pers-dynamic-200-05-09_mixtral_8x22b-instr...
# 5                 1.30  eli-pers-dynamic-100-05-20_command-r-plus_104b...
# 6                 1.54  eli-pers-hybrid-200-05-09_command-r-plus_104b-...
# 7                 1.04  eli-pers-hybrid-200-05-09_mixtral_8x22b-instru...
#
#   survey  ...  prompt_count  \
# 0   pers  ...            50
# 1   pers  ...            50
# 2   pers  ...            50
# 3   pers  ...            50
# 4   pers  ...            50
# 5   pers  ...            50
# 6   pers  ...            50
# 7   pers  ...            50
#
#                                     retrieval prompt  retrieval method  \
# 0  openess conciousness extrovert aggreableness n...            hybrid
# 1  openess conciousness extrovert aggreableness n...           dynamic
# 2  openess conciousness extrovert aggreableness n...           dynamic
# 3  openess conciousness extrovert aggreableness n...            hybrid
# 4  openess conciousness extrovert aggreableness n...           dynamic
# 5  openess conciousness extrovert aggreableness n...           dynamic
# 6  openess conciousness extrovert aggreableness n...            hybrid
# 7  openess conciousness extrovert aggreableness n...            hybrid
#
#    prompt method  tokens_in_chunks CTX_limit CHUNKS_COUNT_IN_CTX OVERLAP_SIZE  \
# 0    IMPERSONATE            695218     30000                  20            5
# 1    IMPERSONATE           1313092     30000                   9            5
# 2    IMPERSONATE           1360011     30000                  20            5
# 3    IMPERSONATE            695218     30000                  20            5
# 4    IMPERSONATE           1313092     30000                   9            5
# 5    IMPERSONATE           1360011     30000                  20            5
# 6    IMPERSONATE            604738     30000                   9            5
# 7    IMPERSONATE            604738     30000                   9            5
#
#    CHUNK_SIZE               date
# 0         100  2024-05-03_174918
# 1         200  2024-05-03_160838
# 2         100  2024-05-03_141503
# 3         100  2024-05-03_165557
# 4         200  2024-05-03_134926
# 5         100  2024-05-03_152108
# 6         200  2024-05-03_143827
# 7         200  2024-05-03_172354
#
# [8 rows x 28 columns]

# %% [markdown]
# #### Multi-Sim

# %%
invalid_vals = []

for index, sim_row in df.iterrows():
    sim = utils.load_sim(sim_row["path"])
    dfa = utils.dataframe_from_QA(sim["QA"])
    with bu.MutePrint():
        surv = get_surv_from_info(sim_row)
    dfa = clean_simulation_QA(dfa)
    if not dfa['isValid'].all():
        print(f"Skipping {sim_row['SIMULATION_ID']} due to invalid answers")
        # show invalid ones
        display(dfa[~dfa['isValid']])
        invalid_vals.extend(dfa.loc[~dfa['isValid'], 'answer'].tolist())
        continue

    dfa = add_airidas_and_elias_answers(dfa, surv)
    dfa = remap_answers_to_integers(dfa, surv)
    res = evaluate_single_simulation_run(dfa)

    # Example condition: set 'B' to double the value of 'A'

    for key, value in res.items():
        df.at[index, key] = round(value, 3)

df = utils.bring_to_front_important_columns(df, MOST_IMPORTANT_COLUMNS)

if len(invalid_vals) > 0:
    print(f"{len(invalid_vals)} Invalid values:")
    print(invalid_vals)
else:
    print("All values are valid")
# Out:
# All values are valid

# %%
# Define how columns should be groped
aggregation_dict = {
    'p-corr_Airidas': ['mean', 'std'],
    'p-corr_Elias': ['mean', 'std'],
    'mean_residual_Airidas': ['mean', 'std'],
    'mean_residual_Elias': ['mean', 'std']
}
# Preserve the first entry of other columns
for col in df.columns:
    if col not in ['sim_signature', *list(aggregation_dict.keys())]:
        aggregation_dict[col] = 'first'
        
# dfg stands for DataFrame Grouped.
dfg = df.groupby('sim_signature').agg(aggregation_dict)

# Renaming MultiIndex columns
dfg.columns = ['_'.join(col).strip() if col[1] != 'first' else col[0] for col in dfg.columns.values]
dfg = dfg.reset_index()
dfg.head(5)
# Out:
# Empty DataFrame
# Columns: [sim_signature, p-corr_Airidas_mean, p-corr_Airidas_std, p-corr_Elias_mean, p-corr_Elias_std, mean_residual_Airidas_mean, mean_residual_Airidas_std, mean_residual_Elias_mean, mean_residual_Elias_std, run_number, model, survey_type, total_all_prompt_tokens, prompt_template, CHUNK_SIZE, OVERLAP_SIZE, CHUNKS_COUNT_IN_CTX, CTX_limit, tokens_in_chunks, prompt method, retrieval method, retrieval prompt, prompt_count, subject, path, date, prompt_tokens_min, prompt_tokens_max, avg_tokens_in_prompt, timeout, survey, SIMULATION_ID]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# ### Vizualisation

# %%
import matplotlib.pyplot as plt

# Assuming 'mean_residual_Airidas_mean' and 'p-corr_Airidas_mean' are already computed as mean values in your aggregated dataframe
# Plotting for Airidas
plt.figure(figsize=(10, 6))
plt.scatter(dfg['p-corr_Airidas_mean'], dfg['mean_residual_Airidas_mean'], label='Airidas', alpha=0.5)

# Assuming 'mean_residual_Elias_mean' and 'p-corr_Elias_mean' are also computed as mean values
# Plotting for Elias
plt.scatter(dfg['p-corr_Elias_mean'], dfg['mean_residual_Elias_mean'], color='red', label='Elias', alpha=0.5)

plt.title('Mean Residuals vs P-Corr')
plt.xlabel('P-Corr (mean)')
plt.ylabel('Mean Residuals (mean)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

dfg = dfg[dfg['retrieval method'] != "static"]
# Set style
sns.set(style="whitegrid")

# Sorting and filtering the dataframe for each plot
sorted_airidas_personality = dfg[(dfg['survey_type'] == 'PersonalitySurvey')].sort_values('p-corr_Airidas_mean', ascending=False)
sorted_airidas_kano = dfg[(dfg['survey_type'] == 'KanoSurvey')].sort_values('p-corr_Airidas_mean', ascending=False)
sorted_elias_personality = dfg[(dfg['survey_type'] == 'PersonalitySurvey')].sort_values('p-corr_Elias_mean', ascending=False)
sorted_elias_kano = dfg[(dfg['survey_type'] == 'KanoSurvey')].sort_values('p-corr_Elias_mean', ascending=False)

# Custom color function that also compares the 'SUBJECT' value
def get_colors_airidas(df):
    colors = []
    for _, row in df.iterrows():
        if row['SUBJECT'] != 'airidas' and not row['is_base']:
            colors.append('black')  # Color these bars black if 'SUBJECT' is not 'airidas'
        elif row['is_base']:
            colors.append('#adcbe3')  # Soft tinted light blue
        else:
            colors.append('#0c4da2')  # Deep blue

    return colors

def get_colors_elias(df):
    colors = []
    for _, row in df.iterrows():
        if row['SUBJECT'] != 'elias' and not row['is_base']:
            colors.append('black')  # Color these bars black if 'SUBJECT' is not 'elias'
        elif row['is_base']:
            colors.append('#adcbe3')  # Soft tinted light blue
        else:
            colors.append('#0c4da2')  # Deep blue

    return colors

# Get colors for each dataset
colors_airidas_p = get_colors_airidas(sorted_airidas_personality)
colors_airidas_k = get_colors_airidas(sorted_airidas_kano)
colors_elias_p = get_colors_elias(sorted_elias_personality)
colors_elias_k = get_colors_elias(sorted_elias_kano)

# Create a figure with subplots
fig, axs = plt.subplots(2, 2, figsize=(14, 14))  # 2 rows, 2 columns
fig.suptitle('Mean p-corr Metrics by Sim Signature and Survey Type', fontsize=16)

# Plotting as horizontal bar charts using sorted data and custom colors
sns.barplot(data=sorted_airidas_personality, y='sim_signature', x='p-corr_Airidas_mean', ax=axs[0, 0], palette=colors_airidas_p, orient='h')
axs[0, 0].set_title('Mean p-corr_Airidas (PersonalitySurvey)')
axs[0, 0].set_xlabel('Mean p-corr_Airidas')
axs[0, 0].set_ylabel('Sim Signature')

sns.barplot(data=sorted_airidas_kano, y='sim_signature', x='p-corr_Airidas_mean', ax=axs[1, 0], palette=colors_airidas_k, orient='h')
axs[1, 0].set_title('Mean p-corr_Airidas (KanoSurvey)')
axs[1, 0].set_xlabel('Mean p-corr_Airidas')
axs[1, 0].set_ylabel('Sim Signature')

sns.barplot(data=sorted_elias_personality, y='sim_signature', x='p-corr_Elias_mean', ax=axs[0, 1], palette=colors_elias_p, orient='h')
axs[0, 1].set_title('Mean p-corr_Elias (PersonalitySurvey)')
axs[0, 1].set_xlabel('Mean p-corr_Elias')
axs[0, 1].set_ylabel('Sim Signature')

sns.barplot(data=sorted_elias_kano, y='sim_signature', x='p-corr_Elias_mean', ax=axs[1, 1], palette=colors_elias_k, orient='h')
axs[1, 1].set_title('Mean p-corr_Elias (KanoSurvey)')
axs[1, 1].set_xlabel('Mean p-corr_Elias')
axs[1, 1].set_ylabel('Sim Signature')

# Adjust layout for readability
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Show plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
dfg = dfg[dfg['SUBJECT'] != "airidas"]
dfg = dfg[dfg['retrieval method'] == "dynamic"]
# Compute mean p-corr_Elias_mean for each unique value of 'CHUNKS_COUNT_IN_CTX'
chunks_count_means = dfg.groupby('CHUNKS_COUNT_IN_CTX')['p-corr_Elias_mean'].mean().reset_index()
chunks_count_means = chunks_count_means.sort_values(by='CHUNKS_COUNT_IN_CTX')

# Plot bar chart for 'CHUNKS_COUNT_IN_CTX'
plt.figure(figsize=(15, 6))
plt.bar(np.arange(len(chunks_count_means)), chunks_count_means['p-corr_Elias_mean'])
plt.xticks(np.arange(len(chunks_count_means)), chunks_count_means['CHUNKS_COUNT_IN_CTX'], rotation=90, ha='right')
plt.subplots_adjust(bottom=0.3)
plt.ylabel('Mean p-corr_Elias_mean')
plt.title('Mean p-corr_Elias_mean by CHUNKS_COUNT_IN_CTX')
plt.show()

# Compute mean p-corr_Elias_mean for each unique value of 'CHUNK_SIZE'
chunk_size_means = dfg.groupby('CHUNK_SIZE')['p-corr_Elias_mean'].mean().reset_index()
chunk_size_means = chunk_size_means.sort_values(by='CHUNK_SIZE')

# Plot bar chart for 'CHUNK_SIZE'
plt.figure(figsize=(15, 6))
plt.bar(np.arange(len(chunk_size_means)), chunk_size_means['p-corr_Elias_mean'])
plt.xticks(np.arange(len(chunk_size_means)), chunk_size_means['CHUNK_SIZE'], rotation=90, ha='right')
plt.subplots_adjust(bottom=0.3)
plt.ylabel('Mean p-corr_Elias_mean')
plt.title('Mean p-corr_Elias_mean by CHUNK_SIZE')
plt.show()

# Compute mean p-corr_Elias_mean for each unique value of 'OVERLAP_SIZE'
overlap_size_means = dfg.groupby('OVERLAP_SIZE')['p-corr_Elias_mean'].mean().reset_index()
overlap_size_means = overlap_size_means.sort_values(by='OVERLAP_SIZE')

# Plot bar chart for 'OVERLAP_SIZE'
plt.figure(figsize=(15, 6))
plt.bar(np.arange(len(overlap_size_means)), overlap_size_means['p-corr_Elias_mean'])
plt.xticks(np.arange(len(overlap_size_means)), overlap_size_means['OVERLAP_SIZE'], rotation=90, ha='right')
plt.subplots_adjust(bottom=0.3)
plt.ylabel('Mean p-corr_Elias_mean')
plt.title('Mean p-corr_Elias_mean by OVERLAP_SIZE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SUBJECT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[238], line 3
#       1 import matplotlib.pyplot as plt
#       2 import numpy as np
# ----> 3 dfg = dfg[dfg['SUBJECT'] != "airidas"]
#       4 dfg = dfg[dfg['retrieval method'] == "dynamic"]
#       5 # Compute mean p-corr_Elias_mean for each unique value of 'CHUNKS_COUNT_IN_CTX'
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'SUBJECT'

# %%
import matplotlib.pyplot as plt
import numpy as np

# Drop rows where SUBJECT == "airidas"
dfg = dfg[dfg['SUBJECT'] != "airidas"]
dfg = dfg[dfg['retrieval method'] == "dynamic"]
# dfg = dfg[dfg['survey_type'] != "PersonaSurvey"]

# Compute mean p-corr_Elias_mean for each unique value of 'retrieval_method'
retrieval_method_means = dfg.groupby('retrieval method')['p-corr_Elias_mean'].mean().reset_index()
retrieval_method_means = retrieval_method_means.sort_values(by='retrieval method')

# Plot bar chart for 'retrieval_method'
plt.figure(figsize=(15, 6))
plt.bar(np.arange(len(retrieval_method_means)), retrieval_method_means['p-corr_Elias_mean'])
plt.xticks(np.arange(len(retrieval_method_means)), retrieval_method_means['retrieval method'], rotation=90, ha='right')
plt.subplots_adjust(bottom=0.3)
plt.ylabel('Mean p-corr_Elias_mean')
plt.title('Mean p-corr_Elias_mean by Retrieval Method')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'SUBJECT'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[239], line 5
#       2 import numpy as np
#       4 # Drop rows where SUBJECT == "airidas"
# ----> 5 dfg = dfg[dfg['SUBJECT'] != "airidas"]
#       6 dfg = dfg[dfg['retrieval method'] == "dynamic"]
#       7 # dfg = dfg[dfg['survey_type'] != "PersonaSurvey"]
#       8
#       9 # Compute mean p-corr_Elias_mean for each unique value of 'retrieval_method'
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'SUBJECT'

# %%
import matplotlib.pyplot as plt
import numpy as np
# Drop rows where SUBJECT == "airidas"
dfg = dfg[dfg['SUBJECT'] != "airidas"]


# Compute mean p-corr_Elias_mean and mean_residual_Elias_std for each unique value of 'retrieval_method'
retrieval_method_means = dfg.groupby('retrieval method')[['p-corr_Elias_mean', 'mean_residual_Elias_std']].mean().reset_index()
retrieval_method_means = retrieval_method_means.sort_values(by='retrieval method')

# Plot bar chart for 'retrieval_method'
fig, ax = plt.subplots(figsize=(15, 6))
bar_width = 0.35
index = np.arange(len(retrieval_method_means))

rects1 = ax.bar(index, retrieval_method_means['p-corr_Elias_mean'], bar_width, label='p-corr_Elias_mean')
rects2 = ax.bar(index + bar_width, retrieval_method_means['mean_residual_Elias_std'], bar_width, label='mean_residual_Elias_std')

ax.set_xlabel('Retrieval Method')
ax.set_ylabel('Mean Value')
ax.set_title('Mean Values by Retrieval Method')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(retrieval_method_means['retrieval method'], rotation=90, ha='right')
ax.legend()

fig.tight_layout()
plt.show()

# %%
import pandas as pd
# Drop rows where SUBJECT == "airidas"
dfg = dfg[dfg['SUBJECT'] != "airidas"]
# Compute summary statistics for each retrieval method
summary_stats = dfg.groupby('retrieval method')[['p-corr_Elias_mean', 'mean_residual_Elias_std']].agg(['mean', 'var', 'std'])
# Reset the multi-index to make the column labels more readable
summary_stats.columns = ['_'.join(col).strip() for col in summary_stats.columns.values]
summary_stats = summary_stats.reset_index()
# Store the summary statistics in a DataFrame
pd.DataFrame(summary_stats)

# %%
systemMsg( "You are participating in a survey. You will be presented with a series of questions about your video game preferrences.", f"You must choose answer to the question below with one of the five options: {', '.join(surv.POSSIBLE_ANSWERS)}. The answer must only contain the chosen option. " ), 
# Understanding affirmation 
assistantMsg('Understood. I will answer the question below with one of the given options.'), 
# Survey question. With Simulation 
userMsg( question, "Your choice: " ),

# %% [markdown]
# systemMsg("\\n".join([
#             f"You are an expert actor, specializing in impersonation of non-famouns people. You will be presented to the subject through explicit datapoints of their digital footprint. In addition, you will deduct their implicit {SURVEY} by shadowing chats between the subject and friends. You will be asked to fully immerse yourself in the role, and answer questions from the point of view of the persona. \\n#Context \\n##Chat conversations between the subject and their friends:\\n**From most to least related**\\n",
#             "\\n\\nNEW CONVERSATION:\\n".join(chunks_most_similar)
#         ])),
#         assistantMsg("Understood. I will answer from the point of view of the persona, based on what I could the deduct from the text provided."),
#         userMsg("\\n".join([
#             f"Persona is questioned about their {SURVEY} in an {METHOD}. The persona must choose an appropriate answer to the question below with one of these five given options: {', '.join(surv.POSSIBLE_ANSWERS)}. Persona's answer must only contain the chosen option, without any elaboration, nor introduction.\\n\\n**Your question is:**\\n",
#             question,
#             "\\nThe persona chooses:"
#         ]))]

# %% [markdown]
# ### THE REAL DEAL

# %%
# ################### Retrieval below ##################
surv = {}
surv['POSSIBLE_ANSWERS'] = ["I LIKE IT", "I EXPECT IT", "I AM NEUTRAL", "I CAN TOLERATE IT", "I DISLIKE IT", "SOMEWHAT DISAGREE", "DISAGREE", "NEUTRAL", "SOMEWHAT AGREE", "AGREE"]

def extract_possible_answer(value):
    for phrase in surv['POSSIBLE_ANSWERS']:
        pattern = r'(?i)' + re.escape(phrase)
        match = re.search(pattern, value)
        if match:
            return match.group()
    return value  # Return the original value if no possible answer is found

############ Invalid Answers ##################
def get_invalid_answers(value):
    if pd.isna(value):
        return ""
    elif value == "NaN":
        return ""
    elif value in surv['POSSIBLE_ANSWERS']:
        return ""
    else:
        return value
    
# surv = survey.PersonalitySurvey()
# surv = survey.KanoSurvey()

# %% [markdown]
# ## Convert Personality survey As into Big 5 ratings

# %%
# Load the simulation results
# both personality and game WIP

dfs = []
filenames = []
# changed_values_per_column = {}

# List of folder paths
# folder_paths = ['simulations/local/video-game/', 'simulations/local/personality/']
# folder_paths = ['batch/output/_pers']
folder_paths = ['batch/output/llama3_70b/kano']#, 'batch/output/_pers']
# pers_folder_path = ['batch/output/_pers']
# kano_folder_path = ['batch/output/_kano']

# Read the first CSV file from the first folder to get the 'question' column
first_folder_path = folder_paths[0]
first_file_path = os.path.join(first_folder_path, os.listdir(first_folder_path)[0])
first_df = pd.read_csv(first_file_path)
questions = first_df['question']
# csv_loop_counter = 0

for folder_path in folder_paths:
    for filename in os.listdir(folder_path):
        if filename.endswith('.csv'):
            file_path = os.path.join(folder_path, filename)
            df = pd.read_csv(file_path)

            # Store the original 'answer' column
            # original_answers = df['answer'].copy()
            
            # # remove all characters from a black list from the column answer
            df['answer'] = df['answer'].apply(lambda x: x.strip())
            for substr in utils.BLACKLIST_ANSWER_SUBSTRINGS:
                df['answer'] = df['answer'].apply(lambda x: re.sub(substr, "", x))
            df['answer'] = df['answer'].str.upper()
            df['answer'] = df['answer'].apply(extract_possible_answer)
            # df['answer'] = df['answer'].apply(get_invalid_answers)
            
            filename_without_ext = filename[:-4]  # Remove the '.csv' extension
            filename_without_simulation = (
                filename_without_ext.replace('_simulation', '')
                                    # .replace('video-', '')
            )  # Remove '_simulation' from the filename
            filenames.append(filename_without_simulation)
            dfs.append(df['answer'])
            # csv_loop_counter += 1

answers_df = pd.concat(dfs, axis=1, keys=filenames)
# answers_df.insert(0, 'question', questions)  # Insert the 'question' column at the beginning
#print(f"Values changed: {changed_format}")
df = answers_df
df[:6]

# %%
REMAP_MISSING_E = {"AGRE": "AGREE", "SOMEWHAT AGRE": "SOMEWHAT AGREE", "SOMEWHAT DISAGRE": "SOMEWHAT DISAGREE", "DISAGRE": "DISAGREE"}
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: REMAP_MISSING_E.get(x, x))

# %% [markdown]
# #### SURVEY (both PERSONALITY and KANO)

# %%
surv = survey.KanoSurvey()
# df['isValid'] = df['answer'].apply(lambda x: x in surv.POSSIBLE_ANSWERS)
# df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: remap_dict.get(x, x))
df['isValid'] = df.iloc[:, 1:].map(lambda x: x in surv.POSSIBLE_ANSWERS).all(axis=1)
if df['isValid'].all():
    df = df.drop('isValid', axis=1)
    print("All answers were valid")
else:
    print("Some answers were not valid")
df.head()

# %%
# surv = survey.PersonalitySurvey()
# surv = survey.KanoSurvey()

# # Add airidas and elias answers
# air = surv.test_answers["airidas"]
# answers_df.insert(1, "airidas", air[:len(df)])
eli = surv.test_answers["elias"]
df.insert(0, "elias", eli[:len(df)])

# df['answer'] = df['answer'].str.upper()
# df['elias'] = df['elias'].str.upper()
# df = df.dropna()
# df[:5]

# %% [markdown]
# ### Process data

# %% [markdown]
# ##### Str2Int

# %%
### Remaps - UNIVERSAL
if isinstance(surv, survey.KanoSurvey):
    remap_dict = {"I EXPECT IT": 5, "I LIKE IT": 4, "I AM NEUTRAL": 3, "I CAN TOLERATE IT": 2, "I DISLIKE IT": 1}
    df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: remap_dict.get(x, x))
    # df['answer'] = df['answer'].map(remap_dict)
    # df['airidas'] = df['airidas'].map(remap_dict)
    # df['elias'] = df['elias'].map(remap_dict)
elif isinstance(surv, survey.PersonalitySurvey):
    remap_dict = {"AGREE": 5, "SOMEWHAT AGREE": 4, "NEUTRAL": 3, "SOMEWHAT DISAGREE": 2, "DISAGREE": 1}
    df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: remap_dict.get(x, x))
    # df.iloc[:, 2:] = df.iloc[:, 2:].map(lambda x: remap_dict[x])
    # remap_cols = df.columns[df.columns.str.contains('|'.join(remap_dict.keys()))]    
    # df['answer'] = df['answer'].map(remap_dict)

df[:2]

# %%
df['elias'] = df['elias'].str.upper()
df['elias'] = df['elias'].map(remap_dict)
df.head()

# %%
# Get correlations with 'elias'
correlations = df.corr()['elias']

# Drop the correlation of 'elias' with itself
correlations = correlations.drop('elias')

# Convert the Series to a DataFrame
new_df = correlations.to_frame().reset_index()

# Rename the columns
new_df.columns = ['column_name', 'correlation']

new_df.to_csv("kano_llama3_70b.csv")

# %% [markdown]
# #### SHIT...

# %%
# df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: int(x) if not pd.isna(x) else x)
# df.iloc[:, 1:] = df.iloc[:, 1:].astype(pd.Int64Dtype())

# %%
import pandas as pd
# df.count_non_matching_fields(df, _PersonalitySurvey_)

def count_non_matching_fields(df, surv):
    if isinstance(surv, survey._KanoSurvey_):
        remap_dict = {"I EXPECT IT": 5, "I LIKE IT": 4, "I AM NEUTRAL": 3, "I CAN TOLERATE IT": 2, "I DISLIKE IT": 1}
        possible_answers = list(remap_dict.keys())

        non_matching_counts = (
            df.iloc[:, 1:]
            .applymap(lambda x: x not in possible_answers)
            .sum()
            .rename("non_matching_count")
        )

        df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: remap_dict.get(x, x))

    elif isinstance(surv, survey._PersonalitySurvey_):
        remap_dict = {"AGREE": 5, "SOMEWHAT AGREE": 4, "NEUTRAL": 3, "SOMEWHAT DISAGREE": 2, "DISAGREE": 1}
        possible_answers = list(remap_dict.keys())

        non_matching_counts = (
            df.iloc[:, 2:]
            .applymap(lambda x: x not in possible_answers)
            .sum()
            .rename("non_matching_count")
        )

        df.iloc[:, 2:] = df.iloc[:, 2:].applymap(lambda x: remap_dict.get(x, x))

    return non_matching_counts
df.head()

# %%
# Assuming your DataFrame is named 'df'
for col in df.columns[1:]:  # Iterate over all columns except the target column
    matches = df.loc[df[col] == df['elias'], col]  # Find rows where values match the target
    print(f"Exact matches for column '{col}': {len(matches)}")

# Compute correlation between each column and the target column
correlations = df.corr()['elias'].drop('elias')
print(correlations)

for col in df.columns[1:]:
    matches = df.loc[df[col] == df['elias'], col]
    print(f"Exact matches for column '{col}': {len(matches)}")

correlations = df.corr()['elias'].drop('elias')
print("\nCorrelations:")
print(correlations)

# %%
df.head()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap="YlGnBu")
plt.title("Correlation Matrix")
plt.show()

# Assuming 'col1' and 'col2' have the highest positive and negative correlations, respectively
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(df['eli_pers_static-IMPERSONATE_5'], df['elias'])
plt.xlabel('eli_pers_static-IMPERSONATE_5')
plt.ylabel('elias')
plt.title('Scatter Plot: eli_pers_static-IMPERSONATE_5 vs. elias')

plt.subplot(1, 2, 2)
plt.scatter(df['eli_pers_static-ARE_1'], df['elias'])
plt.xlabel('eli_pers_static-ARE_1')
plt.ylabel('elias')
plt.title('Scatter Plot: eli_pers_static-ARE_1 vs. elias')

plt.tight_layout()
plt.show()

# %%
df.iloc[:, 1:] = df.iloc[:, 1:].applymap(lambda x: remap_dict.get(x, x))

# %%
valid_answers = ["I LIKE IT", "I EXPECT IT", "I AM NEUTRAL", "I CAN TOLERATE IT", "I DISLIKE IT", "SOMEWHAT DISAGREE", "DISAGREE", "NEUTRAL", "SOMEWHAT AGREE", "AGREE"]#surv['POSSIBLE_ANSWERS']
# Assuming you have a DataFrame 'df' with columns ['col1', 'col2', 'elias', 'col3', 'col4', ...]
# and a set 'valid_answers' containing the valid answer values
# Get the column names except the first two  and 'elias'
cols = [col for col in df.columns[0:] if col != 'elias']
# Create a dictionary to store the computed values
results = {}
# Function to compute "Exact Matches"
def exact_matches(col):
    # Filter the rows where both columns have valid answers
    valid_rows = (df[col].isin(valid_answers)) & (df['elias'].isin(valid_answers))
    # Compute exact matches only for valid rows
    return (df.loc[valid_rows, col] == df.loc[valid_rows, 'elias']).mean()
# Function to compute "Correlation"
def correlation(col):
    # Filter the rows where both columns have valid answers
    valid_rows = (df[col].isin(valid_answers)) & (df['elias'].isin(valid_answers))
    # Compute correlation only for valid rows
    return df.loc[valid_rows, col].corr(df.loc[valid_rows, 'elias'])
# Compute the "Exact Matches" and "Correlation" for each column against 'elias'
for col in cols:
    key1 = f"Exact Matches - {col} vs elias"
    key2 = f"Correlation - {col} vs elias"
    results[key1] = exact_matches(col)
    results[key2] = correlation(col)
# Sort the columns by their correlation with 'elias' in descending order
sorted_cols = sorted(cols, key=lambda col: results[f"Correlation - {col} vs elias"], reverse=True)
# Print the results sorted by correlation, from highest to lowest
for col in sorted_cols:
    em_key = f"Exact Matches - {col} vs elias"
    corr_key = f"Correlation - {col} vs elias"
    print(f"{col}: Exact Matches = {results[em_key]}, Correlation = {results[corr_key]}")

# %% [markdown]
# ##### Embed technique

# %%
############ Embed technique ################
# RETRIEVAL_PROMPT = surv['POSSIBLE_ANSWERS']
PRE_DEF_ANSWERS = ["I LIKE IT", "I EXPECT IT", "I AM NEUTRAL", "I CAN TOLERATE IT", "I DISLIKE IT", "SOMEWHAT DISAGREE", "DISAGREE", "NEUTRAL", "SOMEWHAT AGREE", "AGREE"]

embeddings = [ollama.embeddings(model=EMBED_MODEL, prompt=answer)["embedding"] for answer in PRE_DEF_ANSWERS]

FINAL_STRINGS_2_CLEAN = df['answer'] #change to answers_df['answer'] for all simulations
# utils.find_most_similar(ollama.embeddings(model=EMBED_MODEL, prompt=FINAL_STRINGS_2_CLEAN[0])["embedding"], embeddings)
mapped_results = [utils.find_most_similar(string) for string in FINAL_STRINGS_2_CLEAN]
print(mapped_results)
# Generate embeddings for each chunk
embeddings = []

progress, chunks_len = 0, len(chunks) # for progress bar
for chunk_text in chunks:
    progress += 1
    print(f"\rChunk {progress}/{chunks_len}", end="")

    embedding = ollama.embeddings(model=EMBED_MODEL, prompt=chunk_text)["embedding"]
    embeddings.append(embedding)

bu.if_dir_not_exist_make("data/3_embeddings")
bu.quickJSON(AUTO_INFO, f"data/3_embeddings/POSSIBLE_ANSWERS_info.json")
bu.quickJSON({"chunks": chunks, "embeddings": embeddings}, f"data/3_embeddings/POSSIBLE_ANSWERS_embeddings.json")

# %% [markdown]
# ##### Trash?

# %%
# Import simulation and info sheet
SIMULATION_NAMEID = "airidas-personality_mixtral_cv1" #f"{SIM_ID}"
df = pd.read_csv(f'simulations/local/personality/{SIMULATION_NAMEID}_simulation.csv')
with open(f'simulations/local/personality/{SIMULATION_NAMEID}_info.json', 'r') as f:
    loaded = json.load(f)
try:
    AUTO_INFO = loaded["info"]
    SETTINGS = loaded["settings"]
    print("Settings and info loaded:")
    for k, v in AUTO_INFO.items():
        print(f"{k}: {v}")
    for k, v in SETTINGS.items():
        print(f"{k}: {v}")
except:
    print("No settings and/or info found")
try:
    if str(type(surv)) != AUTO_INFO["survey_type"]:
        print(f"WARNING: surv variable is not of the same type. {str(type(surv))} != {AUTO_INFO['survey_type']}")
except:
    pass
df.head(n=2)

# %%
# LiveCSV
bu.if_dir_not_exist_make("data/6_sim-clean/results")
res = bu.LiveCSV(f"data/6_sim-clean/elias_runs.csv")

# survey = survey.PersonalitySurvey()
non_matching_counts = count_non_matching_fields(df, surv)
print(non_matching_counts)

# %%
# compute one number of how the percentage of correct answers
result_data = {
    # "Exact Matches - airi": (df['answer'] == df['airidas']).sum() / len(df),
    # "Correlation - airi": df['answer'].corr(df['airidas']),
    "Exact Matches - eli": (df['answer'] == df['elias']).sum() / len(df),
    "Correlation - eli": df['answer'].corr(df['elias']),
}
# compute one number of how the percentage of correct answers
# print(f"Exact Matches: {(df['CLONE_eli'] == df['IRL_eli']).sum() / len(df)}")
# print(f"Correlation: {df['CLONE_eli'].corr(df['IRL_eli'])}")
# df['elias_correct'] = df['CLONE_eli'] == df['IRL_eli']
df.iloc[:, 2:] = df.iloc[:, 2:].applymap(lambda x: remap_dict.get(x, x))
for k, v in result_data.items():
    print(f"{k}: {v}")

# %%
new_res = {
    # "label": None,
    "SIMULATION_NAMEID": SIMULATION_NAMEID,#SIM_ID,
    "timestamp": bu.get_timestamp(),
    "survey_type": str(type(surv)),
    # "temperature": SETTINGS["temperature"],
    # "note": "",
    "exact_matches": result_data["Exact Matches"],
    "corr": result_data["Correlation"],
    "exact_matches_elias": result_data["Exact Matches - elias"],
    "corr_elias": result_data["Correlation - elias"],
}

tmp = bu.convert_dicts_to_table([new_res])
res.append_data(tmp[1], tmp[0])

# %% [markdown]
# ##### Cleaning

# %%
# def _get_invalid_answers_(value, surv, invalid_answers_df=None):
#   --||---
#     else:
#         if invalid_answers_df is None:
#             invalid_answers_df = pd.DataFrame({'invalid_answer': [value]})
#         elif invalid_answers_df is not None:
#             invalid_answers_df = invalid_answers_df.append({'invalid_answer': value}, ignore_index=True)
#         else:
#             new_row = pd.DataFrame({'invalid_answer': [value]})
#             invalid_answers_df = pd.concat([invalid_answers_df, new_row], ignore_index=True)
#         return value

#################### ^Retrieval ^ ####################
################ VALIDATION #############
for value in values:
    result = _get_invalid_answers_(value, surv, invalid_answers_df)
    if result == "":
        continue
    elif isinstance(result, pd.DataFrame):
        invalid_answers_df = result
    else:
        print(result)

invalid_answers_df = pd.DataFrame.append(invalid_answers_df, pd.DataFrame({'invalid_answer': [value]}), ignore_index=True)
invalid_answers_df = pd.DataFrame(columns=['invalid_answer'])
# Update isValid
df['isValid'] = df['answer'].apply(lambda x: x in surv.POSSIBLE_ANSWERS)
# ################ VALIDATION #############

# %%
# df['airidas'] = df['airidas'].str.upper()
# df['elias'] = df['elias'].str.upper()
# df['answer'] = df['answer'].map(remap_dict)
# df['airidas'] = df['airidas'].map(remap_dict)
# df['elias'] = df['elias'].map(remap_dict)
########################
# df = df.drop(columns=['uppercase_text'])
# df['CLONE_eli'] = df['answer'].apply(extract_uppercase_text)
# df['CLONE_eli'] = df['CLONE_eli'].str.upper()
# .str.upper() or .lower()
# df['answer'] = df['answer'].map(remap_dict, na_action='ignore')
#df['CLONE_eli'] = df['CLONE_eli'].fillna(0).astype(int)
